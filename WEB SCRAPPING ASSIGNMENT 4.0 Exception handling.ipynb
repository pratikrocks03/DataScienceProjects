# %%
# !pip install selenium

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %% [markdown]
# # Q1) . Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# %%
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/"
driver.get(url)

# %%
# creating empty list
rank=[]
name=[]
artist=[]
u_date=[]
views=[]

# %%
# scrapping details
# name
names=driver.find_elements_by_xpath("//a[@class='mw-redirect']")
for i in names:
    try:
        name.append(i.text)
    except NoSuchElementException:
        name.append("--")
        
# rank        
ranks=driver.find_elements_by_xpath("//td[@align='center']/td[1]")
for i in ranks:
    try:
        rank.append(i.text)
    except NoSuchElementException:
        rank.append("--")
        
# artist        
artists=driver.find_elements_by_xpath("div[@class='mw-parser-output']")
for i in artists:
    try:
        artist.append(i.text)
    except NoSuchElementException:
        artist.append("--")
        
# upload date        
u_dates=driver.find_elements_by_xpath("//td[@align='right']")
for i in u_dates:
    try:
        u_date.append(i.text)
    except NoSuchElementException:
        u_date.append("--")
        
# views        
view=driver.find_elements_by_xpath("//td[@align='center'][1]")
for i in view:
    try:
        views.append(i.text)
    except NoSuchElementException:
        views.append("--")

# %%
# creating dataframe
yt=pd.DataFrame({})
yt['Name']=name
yt['Artist']=artist
yt['Upload Date']=u_date
yt['Views']=views

# %%
yt
# Out:
#                                                  Name  \
# 0                                    Baby Shark Dance
# 1                                    Baby Shark Dance
# 2                          Cocomelon – Nursery Rhymes
# 3                          Cocomelon – Nursery Rhymes
# 4                          Cocomelon – Nursery Rhymes
# ..                                                ...
# 95                                The Gummy Bear Song
# 96  Osito Gominola – Full Spanish Version – The Gu...
# 97                                   Baby Shark Dance
# 98                                             Closer
# 99                         Cocomelon – Nursery Rhymes
#
#                                                Artist        Upload Date  \
# 0         Pinkfong Baby Shark - Kids' Songs & Stories    October 8, 2016
# 1                                          Luis Fonsi   January 30, 2017
# 2   LooLoo Kids - Nursery Rhymes and Children's Songs      April 6, 2015
# ...

# %% [markdown]
# # Q2) Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
url='https://www.bcci.tv/'
driver.get(url)

# %%
# clicking the International fixture page
intr=driver.find_element_by_link_text('INTERNATIONAL')
intr.click()

# %%
# creating empty list
odi=[]
series=[]
date=[]
time=[]
venue=[]

# %%
# scrappig details
# Match title
od=driver.find_elements_by_xpath("//div[@class='fixture__description u-unskewed-text']")
for i in od:
    try:
        odi.append(i.text)
    except NoSuchElementException:
        odi.append('--')

# series
ser=driver.find_elements_by_class_name('fixture__teams') 
for i in ser:
    try:
        series.append(i.text)
    except NoSuchElementException:
        series.append('--')
        
# Date        
dt=driver.find_elements_by_class_name('event-list__date js-date')
for i in dt:
    try:
        date.append(i.text)
    except NoSuchElementException:
        date.append('--')
        
#time        
tm=driver.find_elements_by_class_name('fixture__time')
for i in tm:
    try:
        time.append(i.text)
    except NoSuchElementException:
        time.append('--')

# %%
# creating data frame
fixtures=pd.DataFrame({})
fixtures['ODI TITLE']=odi
fixtures['SERIES']=series
fixtures['DATE(from 13 july 2021, to 10 sep 2021)']
fixtures['TIME']=time

# %%
fixtures
# Out:
#                                 ODI TITLE               SERIES  \
# 0   1st ODI\nR Premadasa Stadium, Colombo  SRI LANKA\nv\nINDIA
# 1   2nd ODI\nR Premadasa Stadium, Colombo  SRI LANKA\nv\nINDIA
# 2   3rd ODI\nR Premadasa Stadium, Colombo  SRI LANKA\nv\nINDIA
# 3  1st T20I\nR Premadasa Stadium, Colombo  SRI LANKA\nv\nINDIA
# 4  2nd T20I\nR Premadasa Stadium, Colombo  SRI LANKA\nv\nINDIA
# 5  3rd T20I\nR Premadasa Stadium, Colombo  SRI LANKA\nv\nINDIA
# 6      1st Test\nTrent Bridge, Nottingham    ENGLAND\nv\nINDIA
# 7                2nd Test\nLord's, London    ENGLAND\nv\nINDIA
# 8             3rd Test\nHeadingley, Leeds    ENGLAND\nv\nINDIA
# 9              4th Test\nThe Oval, London    ENGLAND\nv\nINDIA
#
#   DATE(from 13 july 2021, to 10 sep 2021)       TIME
# 0                                      13  14:30 IST
# 1                                      16  14:30 IST
# 2                                      18  14:30 IST
# 3                                      21  19:00 IST
# ...

# %% [markdown]
# # Q3) Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
driver.findElement(By.xpath("(//*[@class='weblinks'])[2]");

# %%
url='https://www.guru99.com/'
driver.get(url)

# %%
# Locating the searh bar
search=driver.find_element_by_id('gsc-i-id2')
search.send_keys('selenium exception handling')

# %%
# clicking
btn=driver.find_element_by_class_name('gsc-search-button gsc-search-button-v2')
btn.click()

# %%
# creating empty list
Name=[]
description=[]

# %%
#scrapping details
#name
names=driver.find_elements_by_xpath("//atrice[@class='article-info muted']/td[1]")
for i in names:
    try:
        Name.append(i.text)
    except NoSuchElementException:
        Name.append('--')
        
# description        
desc=driver.find_elements_by_xpath("//artice[@class='article-info muted']/td[2]")
for i in desc:
    try:
        description.append(i.text)
    except NoSuchElementException:
        description.append("--")

# %%
# creating dataframe
excep=pd.DataFrame({})
excep['Name']=Name
excep['Description']=description

# %%
excep
# Out:
#                                 Name  \
# 0   ElementClickInterceptedException
# 1    ElementNotInteractableException
# 2      ElementNotSelectableException
# 3         ElementNotVisibleException
# 4       ImeActivationFailedException
# 5           ImeNotAvailableException
# 6       InsecureCertificateException
# 7           InvalidArgumentException
# 8       InvalidCookieDomainException
# 9        InvalidCoordinatesException
# 10      InvalidElementStateException
# 11          InvalidSelectorException
# 12         InvalidSessionIdException
# 13    InvalidSwitchToTargetException
# 14               JavascriptException
# 15    MoveTargetOutOfBoundsException
# 16           NoAlertPresentException
# 17          NoSuchAttributeException
# 18             NoSuchCookieException
# 19            NoSuchElementException
#
#                                           Description
# 0   TimeoutException: Thrown when there is not eno...
# 1   UnableToCreateProfileException: You can open a...
# ...

# %% [markdown]
# # Q4) Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP at current price (19-20)
# D) GSDP at current price (18-19)
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
url='http://statisticstimes.com/'
driver.get(url)

# %%
# Clicking on Economy
ecn_btn=driver.find_element_by_link_text('Economy')
ecn_btn.click()

# %%
# creating empty list
rnk=[]
state=[]
gsdp_=[]
gsdp=[]
share=[]
gdp=[]

# %%
# scraping details
# rank
rk=driver.find_elements_by_xpath("//td[@class='data1']")
for i in rk:
    try:
        rnk.append(i.text)
    except NoSuchElementException:
        rnk.append("--")
        
#state        
st=driver.find_elements_by_xpath("//td[@class='name']")
for i in st:
    try:
        state.append(i.text)
    except NoSuchElementException:
        state.append("--")
        
#   GSDP at current price (19-20)        
gs=driver.find_elements_by_xpath("//tr[@class='row']/td/td/td")
for i in gs:
    try:
        gsdp_.append(i.text)
    except NoSuchElementException:
        gsdp_.append("--")
        
#  GSDP at current price (18-29)         
gp=driver.find_elements_by_xpath("//td[@class='data sorting_1']")
for i in gp:
    try:
        gsdp.append(i.text)
    except NoSuchElementException:
        gsdp.append("--")
    

 # share   
shr=driver.find_elements_by_xpath("//table[@class='display dataTable']/tr/td/td/td/td/td")
for i in shr:
    try:
        share.append(i.text)
    except NoSuchElementException:
        share.append("--")
        
#gdp        
gd=driver.find_elements_by_xpath("//td[@class='data']")
for i in gd:
    try:
        gdp.append(i.text)
    except NoSuchElementException:
        gdp.append("--")

# %%
# creating data frame
India=pd.DataFrame({})
India['Rank']=rnk
India['State']=state
India['GSDP at current price (19-20']=gsdp_
India['GSDP at current price (18-19)']=gsdp
India['Share(18-19) ']=share
India['GDP($ billion)']=gdp

# %%
India
# Out:
#    Rank                      State GSDP at current price (19-20  \
# 0     1                Maharashtra                      375,651
# 1     2                 Tamil Nadu                      574,760
# 2     3              Uttar Pradesh                        2.79%
# 3     4                    Gujarat                       79.957
# 4     5                  Karnataka                      418,868
# ..  ...                        ...                          ...
# 63   30                   Nagaland                        5.086
# 64   31          Arunachal Pradesh                       26,695
# 65   32                    Mizoram                       24,682
# 66   33  Andaman & Nicobar Islands                       32,496
# 67                           India                        0.15%
#
#    GSDP at current price (18-19) Share(18-19)  GDP($ billion)
# 0                      2,632,792             -          4.363
# 1                      1,630,208        13.94%         20,017
# ...

# %% [markdown]
# # Q5) Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
url='https://github.com/'
driver.get(url)

# %%
# clicking on explore button
exp_btn=driver.find_element_by_link_text("Explore")
exp_btn.click()

# %%
# clicking on trending
t_btn=driver.find_element_by_link_text("Trending")
t_btn.click()

# %%
# creating empty list
title=[]
descr=[]
count=[]
lang=[]

# %%
#scrapping detail
# repository title
titles=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']")
for i in titles:
    try:
        title.append(i.text)
    except NoSuchElementException:
        title.append('--')
        
# repository description        
desc=driver.find_elements_by_xpath("//p[@class='col-9 color-text-secondary my-1 pr-4']")
for i in desc:
    try:
        descr.append(i.text)
    except NoSuchElementException:
        descr.append('--')
        
# count
counts=driver.find_elements_by_xpath("//a[@class='Link--muted d-inline-block mr-3']")
for i in counts:
    try:
        count.append(i.text)
    except NoSuchElementException:
        couunt.append('--')
# Language        
lan=driver.find_elements_by_xpath("//span[@itemprop='programmingLanguage']")
for i in lan:
    try:
        lang.append(i.text)
    except NoSuchElementException:
        lang.append('-')

# %%
# creating dataframe
github=pd.DataFrame({})
github['Repository Title']=title
github['Repository Description']=descr
github['Count']=count
github['Language']=lang

# %%
github
# Out:
#                                      Repository Title  \
# 0                    spring-projects / spring-graphql
# 1                          madMAx43v3r / chia-plotter
# 2                               puppeteer / puppeteer
# 3                             SmartKeyerror / Psyduck
# 4                   Sneeds-Feed-and-Seed / sneedacity
# 5                                         o3de / o3de
# 6            EbookFoundation / free-programming-books
# 7                         adamschwartz / magic-of-css
# 8                                        kean / Pulse
# 9                           public-apis / public-apis
# 10                  danistefanovic / build-your-own-x
# 11                          dutchcoders / transfer.sh
# 12                               ultralytics / yolov5
# 13                        firebase / firebase-ios-sdk
# 14                        ankurchavda / SparkLearning
# 15                                  angular / angular
# ...

# %% [markdown]
# # Q6) 6. Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
url='https://www.billboard.com/'
driver.get(url)

# %%
# clicking on chart option
chrt=driver.find_element_by_link_text('CHARTS')
chrt.click()

# %%
# clicking on THE HOT 100
ht=driver.find_element_by_link_text('Hot 100')
ht.click()

# %%
# creating empty list
song=[]
artist=[]
last=[]
peak=[]
note=[]

# %%
# Scrapping deatails

#song name
songs=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
for i in songs:
    try:
        song.append(i.text)
    except NoSuchElementException:
        song.append('--')
#artist name        
artists=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
for i in artists:
    try:
        artist.append(i.text)
    except NoSuchElementException:
        artist.append('--')
        
# last week rank        
lasts=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
for i in lasts:
    try:
        last.append(i.text)
    except NoSuchElementException:
        last.append('--')
        
#weaks on board      
notes=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
for i in notes:
    try:
        note.append(i.text)
    except NoSuchElementException:
        note.append('--')
        
# peak rank        
peaks=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
for i in peaks:
    try:
        peak.append(i.text)
    except NoSuchElementException:
        peak.append('--')

# %%
#creating dataframe
details=pd.DataFrame({})
details['SONG NAME']=song
details['ARTIST NAME']=artist
details['LAST WEEK RANK']=last
details['PEAK RANK']=peak
details['WEEKS ON BOARD NOTES']=note

# %%
details
# Out:
#                                           SONG NAME  \
# 0                                       Butter\nBTS
# 1                          Good 4 U\nOlivia Rodrigo
# 2              Kiss Me More\nDoja Cat Featuring SZA
# 3             Levitating\nDua Lipa Featuring DaBaby
# 4                            Bad Habits\nEd Sheeran
# ..                                              ...
# 95                          Twerkulator\nCity Girls
# 96                              Tombstone\nRod Wave
# 97      Miss The Rage\nTrippie Redd & Playboi Carti
# 98  Rise!\nTyler, The Creator Featuring Daisy World
# 99                     Working\nTate McRae X Khalid
#
#                                  ARTIST NAME LAST WEEK RANK PEAK RANK  \
# 0                                        BTS              1         1
# 1                             Olivia Rodrigo              2         1
# 2                     Doja Cat Featuring SZA              4         3
# ...

# %% [markdown]
# # Q7) Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
# clicking on recruiters option
rec=driver.find_element_by_link_text('RECRUITERS')
rec.click()

# %%
# Loacting search bar for data science
ds=driver.find_element_by_class_name('sugInp')
ds.send_keys('Data Science')

# %%
# clicking on search bar
btn=driver.find_element_by_class_name('btn')
btn.click()

# %%
# creating empty list
nme=[]
desg=[]
comp=[]
skill=[]
loca=[]

# %%
# second url
driver.get('https://www.naukri.com/data-science-recruiters')

# %%
# scrapping details
#name
name=driver.find_elements_by_xpath("//div[@class='recInfo']/span")
for i in name:
    try:
        nme.append(i.text)
    except NoSuchElementException:
        nme.append('--')
        
# designantion        
desgn=driver.find_elements_by_xpath("//span[@class='ellipsis clr']")
for i in desgn:
    try:
        desg.append(i.text)
    except NoSuchElementException:
        desg.append('--')
        
# company
compa=driver.find_elements_by_xpath("//p[@class='highlightable']/a")
for i in compa:
    try:
        comp.append(i.text)
    except NoSuchElementException:
        comp.append('--')
#skills        
skills=driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
for i in skills:
    try:
        skill.append(i.text)
    except NoSuchElementException:
        skill.append('--')
        
# Location        
location=driver.find_elements_by_xpath("//div[@class='vcard']")
for i in location:
    try:
        loca.append(i.text)
    except NoSuchElementException:
        loca.append('--')

# %%
# creating dataframe
job=pd.DataFrame({})
job['Name']=nme
job['Designation']=desg
job['Skills']=skill
job['Company']=comp
job['Location']=loca

# %%
job
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            Data Science Network
# 2                            shravan Kumar Gaddam
# 3                   Shore Infotech India Pvt. Ltd
# 4                        MARSIAN Technologies LLP
# 5                        MARSIAN Technologies LLP
# 6                                    Anik Agrawal
# 7           Enerlytics Software Solutions Pvt Ltd
# 8                                    subhas patel
# 9                                 LibraryXProject
# 10   Abhishek - Only Analytics Hiring - India and
# 11     Apidel Technologies Division of Transpower
# 12  Institute for Financial Management and Resear
# 13                                           IFMR
# 14                                    Balu Ramesh
# 15                    Techvantage Systems Pvt Ltd
# 16                                  Asif Lucknowi
# 17                     Weupskill- Live Wire India
# ...

# %% [markdown]
# # Q8) 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
url="https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"
driver.get(url)

# %%
# creating empty list
book=[]
author=[]
volume=[]
publisher=[]
genre=[]

# %%
# scrapping details
#book name
books=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[2]")
for i in books:
    try:
        book.append(i.text)
    except NoSuchElementException:
        book.append('--')
        
#author name        
authors=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[3]")
for i in authors:
    try:
        author.append(i.text)
    except NoSuchElementException:
        author.append('--')
        
# volume sold        
volumes=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[4]")
for i in volumes:
    try:
        volume.append(i.text)
    except NoSuchElementException:
        volume.append('--')
        
# publisher        
pub=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[5]")
for i in pub:
    try:
        publisher.append(i.text)
    except NoSuchElementException:
        publisher.append('--')
# genre        
gen=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[6]")
for i in gen:
    try:
        genre.append(i.text)
    except NoSuchElementException:
        genre.append('--')

# %%
# creating dataframe
book=pd.DataFrame({})
book['Book Name']=book
book['Author Name']=author
book['Volumes Sold']=volume
book['Publishers']=publisher
book['Genre']=genre

# %%
book
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold       Publishers                        Genre
# ...

# %% [markdown]
# #  Q9) 9. Scrape the details most watched tv series of all time from imdb.com.
#  Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
url='https://www.imdb.com/list/ls095964455/'
driver.get(url)

# %%
# creating empty list
nm=[]
year=[]
gen=[]
run=[]
rate=[]
vote=[]

# %%
# scrapping deatil
#name
nme=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
for i in nme:
    try:
        nm.append(i.text)
    except NoSuchElementException:
        nm.append("--")
#years        
years=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
for i in years:
    try:
        year.append(i.text)
    except NoSuchElementException:
        year.append("--")
        
# Genre        
genr=driver.find_elements_by_xpath("//span[@class='genre']")
for i in genr:
    try:
        gen.append(i.text)
    except NoSuchElementException:
        gen.append("--")
        
# Run time        
runn=driver.find_elements_by_xpath("//span[@class='runtime']")
for i in runn:
    try:
        run.append(i.text)
    except NoSuchElementException:
        run.append("--")
        
#ratings        
rat=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']")
for i in rat:
    try:
        rate.append(i.text)
    except NoSuchElementException:
        rate.append("--")
        
        
#votes
vt=driver.find_elements_by_xpath("//span[@name='nv']")
for i in vt:
    try:
        vote.append(i.text)
    except NoSuchElementException:
        vote.append("--")

# %%
# creating data frame
imdb=pd.DataFrame({})
imdb['Name']=nm
imdb['Year Span']=year
imdb['Genre']=gen
imdb['Run Time']=run
imdb['Ratings']=ra
imdb['Votes']=vote

# %%
imdb
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  1,833,208
# ...

# %% [markdown]
# # Q10) 10. Details of Datasets from UCI machine learning repositories.
#  Url = https://archive.ics.uci.edu/
#  You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the Show All Dataset page through code

# %%
url='https://archive.ics.uci.edu/'
driver.get(url)

# %%
# clicking on show all dataset
data=driver.find_element_by_link_text('View ALL Data Sets')
data.click()

# %%
# creating empty list
d_name=[]
d_typ=[]
tsk=[]
attr=[]
nii=[]
naa=[]

# %%
# scrapping details
# dataset name
dn=driver.find_elements_by_xpath(("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a"))
for i in dn:
    try:
        d_name.append(i.text)
    except NoSuchElementException:
        d_name.appen("--")
        
# dataset type        
dt=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p")
for i in dt:
    try:
        d_typ.append(i.text)
    except NoSuchElementException:
        d_typ.append("--")
        
 # task       
tasks=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p")
for i in tasks:
    try:
        tsk.append(i.text)
    except NoSuchElementException:
        tsk.append("--")
        
#attribute type        
at=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p")
for i in at:
    try:
        attr.append(i.text)
    except NoSuchElementException:
        attr.append("--")
        
# no of instances        
ni=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p")
for i in ni:
    try:
        nii.append(i.text)
    except NoSuchElementException:
        nii.append("--")
        
# no of attributes        
na=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p")
for i in na:
    try:
        naa.append(i.text)
    except NoSuchElementException:
        naa.append("--")

# %%
# year
yers=[]
yr=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p")
for i in yr:
    try:
        yers.append(i.text)
    except NoSuchElementException:
        yers.append("--")

# %%
# creating dataframe
uci=pd.DataFrame({})
uci['Dataset Name']=d_name
uci['Dataset Type']=d_typ
uci['Task']=tsk
uci['Attribute Type']=attr
uci['No of Instances']=nii
uci['No of Attributes']=naa
uci['Year']=yers

# %%
uci
# Out:
#                                  Dataset Name                Dataset Type  \
# 0                                     Abalone                  Data Types
# 1                                       Adult               Multivariate
# 2                                   Annealing               Multivariate
# 3                Anonymous Microsoft Web Data               Multivariate
# 4                                  Arrhythmia
# ..                                        ...                         ...
# 580                Wisesight Sentiment Corpus               Multivariate
# 581  AI4I 2020 Predictive Maintenance Dataset         Multivariate, Text
# 582                          Dry Bean Dataset  Multivariate, Time-Series
# 583          in-vehicle coupon recommendation               Multivariate
# 584                       Gait Classification               Multivariate
#
#                                               Task  \
# 0                                     Default Task
# ...
