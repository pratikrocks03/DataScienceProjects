# %% [markdown]
# # 1)  python program to display all the header tags from ‘en.wikipedia.org/wiki/Main_Page’.

# %%
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in c:\programdata\anaconda2\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda2\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda2\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)
# Requirement already satisfied: requests in c:\programdata\anaconda2\lib\site-packages (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda2\lib\site-packages (from requests) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda2\lib\site-packages (from requests) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda2\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda2\lib\site-packages (from requests) (2.10)

# %% [markdown]
# IMPORTING LIBRARIES

# %%
from bs4 import BeautifulSoup 
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# SENDING REQUESTS TO THE WEBPAGE

# %%
page=requests.get('https://en.wikipedia.org/wiki/Main_Page?')
page
# Out:
# <Response [200]>

# %% [markdown]
# MODIFYING THE CONTENT IN SEQUENTIAL FORM

# %%
soup=BeautifulSoup(page.content)

# %% [markdown]
# SHOWING INDENTATION

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Wikipedia, the free encyclopedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"38249fe3-e71b-4f9a-ab70-b80e6b1b2ede","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":1004593520,"wgRevisionId":1004593520,"wgArticleId":15580374,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditable":!1,"wgRelevantPageIsProbablyEditable":!1,"wgRestrictionEdit":["sysop"],"wgRestrictionMove":["sysop"],"wgIsMainPage":!0,"wgFlaggedRevsParams":{
# "tags":{"status":{"levels":-1}}},"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsFlags":10,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgGENewcomerTasksGuidanceEnabled":!0,"wgGEAskQuestionEnabled":!1,"wgGELinkRecommendationsFrontendEnabled":!1,"wgWikibaseItemId":"Q5296"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","skins.vector.styles.legacy":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":
# "ready"};RLPAGEMODULES=["site","mediawiki.page.ready","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.growthExperiments.SuggestedEditSession"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cskins.vector.styles.legacy&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.37.0-wmf.6" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/5/54/Marshal_Tito_during_the_Second_World_War_in_Yugoslavia%2C_May_1944.jpg" property="og:image"/>
#   <meta content="Wikipedia, the free encyclopedia" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <link href="//upload.wikimedia.org" rel="preconnect"/>
#   <link href="//en.m.wikipedia.org/wiki/Main_Page" media="only screen and (max-width: 720px)" rel="alternate"/>
#   <link href="/w/api.php?action=featuredfeed&amp;feed=potd&amp;feedformat=atom" rel="alternate" title="Wikipedia picture of the day feed" type="application/atom+xml"/>
#   <link href="/w/api.php?action=featuredfeed&amp;feed=featured&amp;feedformat=atom" rel="alternate" title="Wikipedia featured articles feed" type="application/atom+xml"/>
#   <link href="/w/api.php?action=featuredfeed&amp;feed=onthisday&amp;feedformat=atom" rel="alternate" title='Wikipedia "On this day..." feed' type="application/atom+xml"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="https://en.wikipedia.org/wiki/Main_Page" rel="canonical"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Main_Page rootpage-Main_Page skin-vector action-view skin-vector-legacy">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators">
#    </div>
#    <h1 class="firstHeading" id="firstHeading">
#     Main Page
#    </h1>
#    <div class="vector-body" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="contentSub2">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#searchInput">
#      Jump to search
#     </a>
#     <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <style data-mw-deduplicate="TemplateStyles:r1004580458">
#        .mw-parser-output #mp-topbanner{position:relative;box-sizing:border-box;min-width:47em;border-color:#ddd;background-color:#f9f9f9;white-space:nowrap}.mw-parser-output .mp-bordered,.mw-parser-output .mp-h2,body.skin-timeless .mw-parser-output .mp-h2{border-width:1px;border-style:solid}.mw-parser-output #mp-topbanner,.mw-parser-output .mp-h2,.mw-parser-output #mp-left{color:#000}.mw-parser-output #mp-welcomecount{margin:0.4em;width:22em;text-align:center}.mw-parser-output #mp-welcome{font-size:162%;padding:0.1em}.mw-parser-output #mp-free{font-size:95%}.mw-parser-output #articlecount{font-size:85%}.mw-parser-output #mp-portals{position:absolute;right:-1em;top:50%;margin-top:-2.4em;width:38%;min-width:25em;font-size:95%}.mw-parser-output #mp-portals li{position:absolute;left:0;top:0}.mw-parser-output #mp-portals .portal-hmid{left:33%}.mw-parser-output #mp-portals .portal-hright{left:66%}.mw-parser-output #mp-portals .portal-vmid{top:1.6em}.mw-parser-output #mp-portals .portal-vbot{top:3.2em}.mw-parser-output #mp-portals li:last-child{font-weight:bold}.mw-parser-output #mp-banner{margin-top:4px;padding:0.5em;background-color:#fffaf5;border-color:#f2e0ce}.mw-parser-output .mp-h2,body.skin-timeless .mw-parser-output .mp-h2{margin:0.5em;padding:0.2em 0.4em;font-size:120%;font-weight:bold;font-family:inherit}.mw-parser-output h2.mp-h2::after{border:none}.mw-parser-output .mp-later{font-size:85%;font-weight:normal}.mw-parser-output #mp-upper{width:100%;margin-top:4px;margin-bottom:0;border-spacing:0;border-collapse:separate}.mw-parser-output #mp-upper .mid-table{border-color:transparent}.mw-parser-output #mp-left{width:55%;border-color:#cef2e0;background:#f5fffa}.mw-parser-output #mp-right{width:45%;border-color:#cedff2;background:#f5faff}.mw-parser-output #mp-left,.mw-parser-output #mp-right{padding:0;vertical-align:top}.mw-parser-output #mp-left .mp-h2{background:#cef2e0;border-color:#a3bfb1}.mw-parser-output #mp-right .mp-h2{background:#cedff2;border-color:#a3b0bf}.mw-parser-output #mp-tfa,.mw-parser-output #mp-dyk,.mw-parser-output #mp-itn,.mw-parser-output #mp-otd,.mw-parser-output #mp-other-lower>div{padding:0.1em 0.6em}.mw-parser-output #mp-dyk-h2,.mw-parser-output #mp-otd-h2{clear:both}.mw-parser-output #mp-middle{margin-top:4px;border-color:#f2cedd;background:#fff5fa}.mw-parser-output #mp-middle,.mw-parser-output #mp-lower,.mw-parser-output #mp-other-lower{overflow:auto}.mw-parser-output #mp-tfl-h2{background:#f2cedd;border-color:#bfa3af}.mw-parser-output #mp-tfl{padding:0.3em 0.7em}.mw-parser-output #mp-lower{margin-top:4px;border-color:#ddcef2;background:#faf5ff}.mw-parser-output #mp-tfp-h2{background:#ddcef2;border-color:#afa3bf}.mw-parser-output #mp-tfp{margin:0.1em 0.4em 0.6em}.mw-parser-output #mp-other-lower{padding:0;border-color:#e2e2e2;margin-top:4px}.mw-parser-output #mp-dyk,.mw-parser-output #mp-otd,.mw-parser-output #mp-other-lower{padding-bottom:0.5em}.mw-parser-output #mp-other-lower .mp-h2{background:#eee;border-color:#ddd;color:#222}@media(max-width:875px){body.skin--responsive .mw-parser-output #mp-welcomecount{width:auto}body.skin--responsive .mw-parser-output #mp-topbanner{min-width:0;white-space:normal}body.skin--responsive .mw-parser-output #mp-portals{position:static;width:auto;min-width:0;text-align:center;border-top:1px solid #ddd;padding:0.4em 0;margin:0 0.4em}body.skin--responsive .mw-parser-output #mp-portals li{position:static;display:inline;padding:0 5px;white-space:nowrap}body.skin--responsive .mw-parser-output table,body.skin--responsive .mw-parser-output tr,body.skin--responsive .mw-parser-output td,body.skin--responsive .mw-parser-output tbody{display:block!important;width:100%!important;box-sizing:border-box}body.skin--responsive .mw-parser-output #mp-tfp tr:first-child td:first-child a{text-align:center;display:table;margin:0 auto}}
#       </style>
#       <div class="mp-bordered" id="mp-topbanner">
#        <div id="mp-welcomecount">
#         <div id="mp-welcome">
#          Welcome to
#          <a href="/wiki/Wikipedia" title="Wikipedia">
#           Wikipedia
#          </a>
#          ,
#         </div>
#         <div id="mp-free">
#          the
#          <a href="/wiki/Free_content" title="Free content">
#           free
#          </a>
#          <a href="/wiki/Encyclopedia" title="Encyclopedia">
#           encyclopedia
#          </a>
#          that
#          <a href="/wiki/Help:Introduction_to_Wikipedia" title="Help:Introduction to Wikipedia">
#           anyone can edit
#          </a>
#          .
#         </div>
#         <div id="articlecount">
#          <a href="/wiki/Special:Statistics" title="Special:Statistics">
#           6,304,249
#          </a>
#          articles in
#          <a href="/wiki/English_language" title="English language">
#           English
#          </a>
#         </div>
#        </div>
#        <ul id="mp-portals">
#         <li>
#          <a href="/wiki/Portal:The_arts" title="Portal:The arts">
#           The arts
#          </a>
#         </li>
#         <li class="portal-vmid">
#          <a href="/wiki/Portal:Biography" title="Portal:Biography">
#           Biography
#          </a>
#         </li>
#         <li class="portal-vbot">
#          <a href="/wiki/Portal:Geography" title="Portal:Geography">
#           Geography
#          </a>
#         </li>
#         <li class="portal-hmid">
#          <a href="/wiki/Portal:History" title="Portal:History">
#           History
#          </a>
#         </li>
#         <li class="portal-hmid portal-vmid">
#          <a href="/wiki/Portal:Mathematics" title="Portal:Mathematics">
#           Mathematics
#          </a>
#         </li>
#         <li class="portal-hmid portal-vbot">
#          <a href="/wiki/Portal:Science" title="Portal:Science">
#           Science
#          </a>
#         </li>
#         <li class="portal-hright">
#          <a href="/wiki/Portal:Society" title="Portal:Society">
#           Society
#          </a>
#         </li>
#         <li class="portal-hright portal-vmid">
#          <a href="/wiki/Portal:Technology" title="Portal:Technology">
#           Technology
#          </a>
#         </li>
#         <li class="portal-hright portal-vbot">
#          <a href="/wiki/Wikipedia:Contents/Portals" title="Wikipedia:Contents/Portals">
#           All portals
#          </a>
#         </li>
#        </ul>
#       </div>
#       <table id="mp-upper" role="presentation">
#        <tbody>
#         <tr>
#          <td class="MainPageBG mp-bordered" id="mp-left">
#           <h2 class="mp-h2" id="mp-tfa-h2">
#            <span id="From_today.27s_featured_article">
#            </span>
#            <span class="mw-headline" id="From_today's_featured_article">
#             From today's featured article
#            </span>
#           </h2>
#           <div id="mp-tfa">
#            <div id="mp-tfa-img" style="float: left; margin: 0.5em 0.9em 0.4em 0em;">
#             <div class="thumbinner mp-thumb" style="background: transparent; border: none; padding: 0; max-width: 141px;">
#              <a class="image" href="/wiki/File:Marshal_Tito_during_the_Second_World_War_in_Yugoslavia,_May_1944.jpg" title="Josip Broz Tito (far right) with his ministers and staff">
#               <img alt="Josip Broz Tito (far right) with his ministers and staff" data-file-height="786" data-file-width="800" decoding="async" height="139" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/54/Marshal_Tito_during_the_Second_World_War_in_Yugoslavia%2C_May_1944.jpg/141px-Marshal_Tito_during_the_Second_World_War_in_Yugoslavia%2C_May_1944.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/54/Marshal_Tito_during_the_Second_World_War_in_Yugoslavia%2C_May_1944.jpg/212px-Marshal_Tito_during_the_Second_World_War_in_Yugoslavia%2C_May_1944.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/54/Marshal_Tito_during_the_Second_World_War_in_Yugoslavia%2C_May_1944.jpg/282px-Marshal_Tito_during_the_Second_World_War_in_Yugoslavia%2C_May_1944.jpg 2x" width="141"/>
#              </a>
#              <div class="thumbcaption" style="padding: 0.25em 0; word-wrap: break-word;">
#               Josip Broz Tito (far right) with his ministers and staff
#              </div>
#             </div>
#            </div>
#            <p>
#             <b>
#              <a href="/wiki/Operation_R%C3%B6sselsprung_(1944)" title="Operation Rösselsprung (1944)">
#               Operation Rösselsprung
#              </a>
#             </b>
#             was a combined
#             <a href="/wiki/Airborne_forces" title="Airborne forces">
#              airborne
#             </a>
#             and ground assault by the German
#             <a href="/wiki/XV_Mountain_Corps_(Wehrmacht)" title="XV Mountain Corps (Wehrmacht)">
#              XV Mountain Corps
#             </a>
#             on the
#             <a href="/wiki/Supreme_Headquarters_(Yugoslav_Partisans)" title="Supreme Headquarters (Yugoslav Partisans)">
#              Supreme Headquarters
#             </a>
#             of the
#             <a href="/wiki/Yugoslav_Partisans" title="Yugoslav Partisans">
#              Yugoslav Partisans
#             </a>
#             during
#             <a href="/wiki/World_War_II" title="World War II">
#              World War II
#             </a>
#             . Launched on 25 May 1944, the operation was aimed at the Partisan leader Marshal
#             <a href="/wiki/Josip_Broz_Tito" title="Josip Broz Tito">
#              Josip Broz Tito
#             </a>
#             <i>
#              (pictured)
#             </i>
#             and his headquarters. It is associated with the
#             <a href="/wiki/Seven_Enemy_Offensives" title="Seven Enemy Offensives">
#              Seventh Enemy Offensive
#             </a>
#             . The operation involved
#             <a href="/wiki/Direct_action_(military)" title="Direct action (military)">
#              direct action
#             </a>
#             via an airborne assault by the
#             <a href="/wiki/500th_SS_Parachute_Battalion" title="500th SS Parachute Battalion">
#              500th SS Parachute Battalion
#             </a>
#             and a planned subsequent link-up with ground forces, including
#             <a href="/wiki/Croatian_Home_Guard_(World_War_II)" title="Croatian Home Guard (World War II)">
#              Home Guard
#             </a>
#             forces of the Independent State of Croatia and
#             <a href="/wiki/Collaborationism" title="Collaborationism">
#              collaborationist
#             </a>
#             <a href="/wiki/Chetniks" title="Chetniks">
#              Chetniks
#             </a>
#             . Tito, his principal staff and
#             <a href="/wiki/Allies_of_World_War_II" title="Allies of World War II">
#              Allied
#             </a>
#             military personnel escaped. The operation failed due to fierce Partisan resistance, the failure of the various German
#             <a href="/wiki/Military_intelligence" title="Military intelligence">
#              intelligence agencies
#             </a>
#             to share the limited intelligence available on Tito's exact location, and the lack of
#             <a href="/wiki/Contingency_plan" title="Contingency plan">
#              contingency planning
#             </a>
#             by the commander of the German airborne force. (
#             <b>
#              <a href="/wiki/Operation_R%C3%B6sselsprung_(1944)" title="Operation Rösselsprung (1944)">
#               Full article...
#              </a>
#             </b>
#             )
#            </p>
#            <div class="tfa-recent" style="text-align: right;">
#             Recently featured:
#             <div class="hlist hlist-separated inline">
#              <ul>
#               <li>
#                <i>
#                 <a href="/wiki/Final_Fantasy_IX" title="Final Fantasy IX">
#                  Final Fantasy IX
#                 </a>
#                </i>
#               </li>
#               <li>
#                <a href="/wiki/Western_Chalukya_literature_in_Kannada" title="Western Chalukya literature in Kannada">
#                 Western Chalukya literature in Kannada
#                </a>
#               </li>
#               <li>
#                <a href="/wiki/Opening_of_the_Liverpool_and_Manchester_Railway" title="Opening of the Liverpool and Manchester Railway">
#                 Opening of the Liverpool and Manchester Railway
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class="tfa-footer hlist hlist-separated noprint" style="text-align: right;">
#             <ul>
#              <li>
#               <b>
#                <a href="/wiki/Wikipedia:Today%27s_featured_article/May_2021" title="Wikipedia:Today's featured article/May 2021">
#                 Archive
#                </a>
#               </b>
#              </li>
#              <li>
#               <b>
#                <a class="extiw" href="https://lists.wikimedia.org/mailman/listinfo/daily-article-l" title="mail:daily-article-l">
#                 By email
#                </a>
#               </b>
#              </li>
#              <li>
#               <b>
#                <a href="/wiki/Wikipedia:Featured_articles" title="Wikipedia:Featured articles">
#                 More featured articles
#                </a>
#               </b>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <h2 class="mp-h2" id="mp-dyk-h2">
#            <span class="mw-headline" id="Did_you_know_...">
#             Did you know ...
#            </span>
#           </h2>
#           <div id="mp-dyk">
#            <div class="dyk-img" style="float: right; margin-left: 0.5em;">
#             <div class="thumbinner mp-thumb" style="background: transparent; border: none; padding: 0; max-width: 120px;">
#              <a class="image" href="/wiki/File:Portrait_of_a_man_by_Rashid_Mahdi.jpg" title="Photograph of a man by Rashid Mahdi">
#               <img alt="Photograph of a man by Rashid Mahdi" data-file-height="1400" data-file-width="1024" decoding="async" height="164" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Portrait_of_a_man_by_Rashid_Mahdi.jpg/120px-Portrait_of_a_man_by_Rashid_Mahdi.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Portrait_of_a_man_by_Rashid_Mahdi.jpg/180px-Portrait_of_a_man_by_Rashid_Mahdi.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/19/Portrait_of_a_man_by_Rashid_Mahdi.jpg/240px-Portrait_of_a_man_by_Rashid_Mahdi.jpg 2x" width="120"/>
#              </a>
#              <div class="thumbcaption" style="padding: 0.25em 0; word-wrap: break-word;">
#               Photograph of a man by Rashid Mahdi
#              </div>
#             </div>
#            </div>
#            <ul>
#             <li>
#              ... that the work
#              <i>
#               (example pictured)
#              </i>
#              of Sudanese visual artist
#              <b>
#               <a href="/wiki/Rashid_Mahdi" title="Rashid Mahdi">
#                Rashid Mahdi
#               </a>
#              </b>
#              was discovered by a French photographer in the dusty backrooms of several stores?
#             </li>
#             <li>
#              ... that the unfinished
#              <b>
#               <a href="/wiki/Interstate_405_(Oregon)" title="Interstate 405 (Oregon)">
#                Interstate 405
#               </a>
#              </b>
#              was used to mark the border between two of Oregon's congressional districts?
#             </li>
#             <li>
#              ... that
#              <b>
#               <a href="/wiki/Lachlan_Power" title="Lachlan Power">
#                Lachlan Power
#               </a>
#              </b>
#              became the first Australian gaming
#              <a href="/wiki/Content_creation" title="Content creation">
#               content creator
#              </a>
#              to reach 10 million subscribers on
#              <a href="/wiki/YouTube" title="YouTube">
#               YouTube
#              </a>
#              ?
#             </li>
#             <li>
#              ... that the UFC's
#              <a href="/wiki/Dana_White" title="Dana White">
#               Dana White
#              </a>
#              said that
#              <i>
#               <b>
#                <a href="/wiki/EliteXC:_Heat" title="EliteXC: Heat">
#                 EliteXC: Heat
#                </a>
#               </b>
#              </i>
#              was "fucking illegal" over allegations of fight tampering in the main event involving
#              <a href="/wiki/Kimbo_Slice" title="Kimbo Slice">
#               Kimbo Slice
#              </a>
#              ?
#             </li>
#             <li>
#              ... that in 1886 prison superintendent
#              <b>
#               <a href="/wiki/John_W._Tyler" title="John W. Tyler">
#                John W. Tyler
#               </a>
#              </b>
#              took 34 Indians, mostly prisoners, to the
#              <a href="/wiki/Colonial_and_Indian_Exhibition" title="Colonial and Indian Exhibition">
#               Colonial and Indian Exhibition
#              </a>
#              in London to show their skill in carpet weaving?
#             </li>
#             <li>
#              ... that Canadian prime minister
#              <a href="/wiki/Justin_Trudeau" title="Justin Trudeau">
#               Justin Trudeau
#              </a>
#              made an unannounced visit to a
#              <a href="/wiki/McDonald%27s" title="McDonald's">
#               McDonald's
#              </a>
#              at the
#              <b>
#               <a href="/wiki/Whitby_Mall" title="Whitby Mall">
#                Whitby Mall
#               </a>
#              </b>
#              ?
#             </li>
#             <li>
#              ... that, though a poet like her famous great-uncle
#              <a href="/wiki/Henry_Wadsworth_Longfellow" title="Henry Wadsworth Longfellow">
#               Henry Wadsworth
#              </a>
#              ,
#              <b>
#               <a href="/wiki/Stephanie_Longfellow" title="Stephanie Longfellow">
#                Stephanie Longfellow
#               </a>
#              </b>
#              found fame as an actress?
#             </li>
#             <li>
#              ... that
#              <i>
#               <b>
#                <a href="/wiki/Zealot:_A_Book_About_Cults" title="Zealot: A Book About Cults">
#                 Zealot: A Book About Cults
#                </a>
#               </b>
#              </i>
#              suggests someone might join a cult when their lifestyle "doesn't let them have enough sex with aliens"?
#             </li>
#            </ul>
#            <div class="dyk-footer hlist noprint" style="margin-top: 0.5em; text-align: right;">
#             <ul>
#              <li>
#               <b>
#                <a href="/wiki/Wikipedia:Recent_additions" title="Wikipedia:Recent additions">
#                 Archive
#                </a>
#               </b>
#              </li>
#              <li>
#               <b>
#                <a href="/wiki/Help:Your_first_article" title="Help:Your first article">
#                 Start a new article
#                </a>
#               </b>
#              </li>
#              <li>
#               <b>
#                <a href="/wiki/Template_talk:Did_you_know" title="Template talk:Did you know">
#                 Nominate an article
#                </a>
#               </b>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#          <td class="mp-bordered mid-table">
#          </td>
#          <td class="MainPageBG mp-bordered" id="mp-right">
#           <h2 class="mp-h2" id="mp-itn-h2">
#            <span class="mw-headline" id="In_the_news">
#             In the news
#            </span>
#           </h2>
#           <div id="mp-itn">
#            <div class="itn-img" role="figure" style="float: right; margin-left: 0.5em; margin-top: 0.2em;">
#             <div class="thumbinner mp-thumb" style="background: transparent; border: none; padding: 0; max-width: 136px;">
#              <a class="image" href="/wiki/File:MickelsonTPCAwardCeremonyClipped.png" title="Phil Mickelson in 2007">
#               <img alt="Phil Mickelson in 2007" data-file-height="669" data-file-width="635" decoding="async" height="143" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2c/MickelsonTPCAwardCeremonyClipped.png/136px-MickelsonTPCAwardCeremonyClipped.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2c/MickelsonTPCAwardCeremonyClipped.png/204px-MickelsonTPCAwardCeremonyClipped.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2c/MickelsonTPCAwardCeremonyClipped.png/272px-MickelsonTPCAwardCeremonyClipped.png 2x" width="136"/>
#              </a>
#              <div class="thumbcaption" style="padding: 0.25em 0; word-wrap: break-word; text-align: left;">
#               Phil Mickelson
#              </div>
#             </div>
#            </div>
#            <ul>
#             <li>
#              In
#              <a href="/wiki/Golf" title="Golf">
#               golf
#              </a>
#              ,
#              <a href="/wiki/Phil_Mickelson" title="Phil Mickelson">
#               Phil Mickelson
#              </a>
#              <i>
#               (pictured)
#              </i>
#              wins
#              <b>
#               <a href="/wiki/2021_PGA_Championship" title="2021 PGA Championship">
#                the PGA Championship
#               </a>
#              </b>
#              .
#             </li>
#             <li>
#              Journalist
#              <a href="/wiki/Roman_Protasevich" title="Roman Protasevich">
#               Roman Protasevich
#              </a>
#              is arrested after
#              <b>
#               <a href="/wiki/Ryanair_Flight_4978" title="Ryanair Flight 4978">
#                his Ryanair flight
#               </a>
#              </b>
#              is forced to land at
#              <a href="/wiki/Minsk_National_Airport" title="Minsk National Airport">
#               Minsk National Airport
#              </a>
#              in Belarus.
#             </li>
#             <li>
#              <b>
#               <a href="/wiki/Stresa-Mottarone_cable_car_disaster" title="Stresa-Mottarone cable car disaster">
#                A cable car accident
#               </a>
#              </b>
#              near
#              <a href="/wiki/Lake_Maggiore" title="Lake Maggiore">
#               Lake Maggiore
#              </a>
#              in Italy kills 14 people.
#             </li>
#             <li>
#              Due to extreme weather, 21
#              <a href="/wiki/Trail_running" title="Trail running">
#               trail runners
#              </a>
#              <b>
#               <a href="/wiki/Gansu_ultramarathon_disaster" title="Gansu ultramarathon disaster">
#                die in an ultramarathon
#               </a>
#              </b>
#              held in
#              <a href="/wiki/Jingtai_County" title="Jingtai County">
#               Jingtai
#              </a>
#              , China.
#             </li>
#             <li>
#              In the Democratic Republic of the Congo,
#              <a href="/wiki/Mount_Nyiragongo" title="Mount Nyiragongo">
#               Mount Nyiragongo
#              </a>
#              volcano
#              <b>
#               <a href="/wiki/2021_Mount_Nyiragongo_eruption" title="2021 Mount Nyiragongo eruption">
#                erupts
#               </a>
#              </b>
#              , destroying residential areas north of
#              <a href="/wiki/Goma" title="Goma">
#               Goma
#              </a>
#              and forcing people to evacuate.
#             </li>
#            </ul>
#            <div class="itn-footer" style="margin-top: 0.5em;">
#             <div>
#              <b>
#               <a href="/wiki/Portal:Current_events" title="Portal:Current events">
#                Ongoing
#               </a>
#              </b>
#              :
#              <div class="hlist hlist-separated inline">
#               <ul>
#                <li>
#                 <a href="/wiki/COVID-19_pandemic" title="COVID-19 pandemic">
#                  COVID-19 pandemic
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div>
#              <b>
#               <a href="/wiki/Deaths_in_2021" title="Deaths in 2021">
#                Recent deaths
#               </a>
#              </b>
#              :
#              <div class="hlist hlist-separated inline">
#               <ul>
#                <li>
#                 <a href="/wiki/Max_Mosley" title="Max Mosley">
#                  Max Mosley
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Sunderlal_Bahuguna" title="Sunderlal Bahuguna">
#                  Sunderlal Bahuguna
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Ki._Rajanarayanan" title="Ki. Rajanarayanan">
#                  Ki. Rajanarayanan
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Joe_Beckwith" title="Joe Beckwith">
#                  Joe Beckwith
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Klemen_Tinal" title="Klemen Tinal">
#                  Klemen Tinal
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Nizamuddin_Asir_Adrawi" title="Nizamuddin Asir Adrawi">
#                  Nizamuddin Asir Adrawi
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#            <div class="itn-footer hlist hlist-separated noprint" style="text-align: right;">
#             <ul>
#              <li>
#               <b>
#                <a href="/wiki/Wikipedia:In_the_news/Candidates" title="Wikipedia:In the news/Candidates">
#                 Nominate an article
#                </a>
#               </b>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <h2 class="mp-h2" id="mp-otd-h2">
#            <span class="mw-headline" id="On_this_day">
#             On this day
#            </span>
#           </h2>
#           <div id="mp-otd">
#            <p>
#             <b>
#              <a href="/wiki/May_25" title="May 25">
#               May 25
#              </a>
#             </b>
#             :
#             <b>
#              <a href="/wiki/Africa_Day" title="Africa Day">
#               Africa Day
#              </a>
#             </b>
#             (
#             <a href="/wiki/1963" title="1963">
#              1963
#             </a>
#             );
#             <b>
#              <a href="/wiki/First_National_Government" title="First National Government">
#               Anniversary of the First National Government
#              </a>
#             </b>
#             in Argentina (
#             <a href="/wiki/1810" title="1810">
#              1810
#             </a>
#             );
#             <a href="/wiki/Independence_Day_(Jordan)" title="Independence Day (Jordan)">
#              Independence Day
#             </a>
#             in
#             <b>
#              <a href="/wiki/Jordan" title="Jordan">
#               Jordan
#              </a>
#             </b>
#             (
#             <a href="/wiki/1946" title="1946">
#              1946
#             </a>
#             )
#            </p>
#            <div id="mp-otd-img" style="float:right;margin-left:0.5em;">
#             <div class="thumbinner mp-thumb" style="background: transparent; border: none; padding: 0; max-width: 172px;">
#              <a class="image" href="/wiki/File:20090529_Great_Wall_8185.jpg" title="Great Wall of China">
#               <img alt="Great Wall of China" data-file-height="2000" data-file-width="3008" decoding="async" height="114" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/20090529_Great_Wall_8185.jpg/172px-20090529_Great_Wall_8185.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/20090529_Great_Wall_8185.jpg/258px-20090529_Great_Wall_8185.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/10/20090529_Great_Wall_8185.jpg/344px-20090529_Great_Wall_8185.jpg 2x" width="172"/>
#              </a>
#              <div class="thumbcaption" style="padding: 0.25em 0; word-wrap: break-word;">
#               Great Wall of China
#              </div>
#             </div>
#            </div>
#            <ul>
#             <li>
#              <a href="/wiki/1644" title="1644">
#               1644
#              </a>
#              –
#              <a href="/wiki/Transition_from_Ming_to_Qing" title="Transition from Ming to Qing">
#               Ming–Qing transition
#              </a>
#              :
#              <a href="/wiki/Ming_dynasty" title="Ming dynasty">
#               Ming
#              </a>
#              general
#              <a href="/wiki/Wu_Sangui" title="Wu Sangui">
#               Wu Sangui
#              </a>
#              allowed the invading
#              <a href="/wiki/Manchu_people" title="Manchu people">
#               Manchu
#              </a>
#              to pass through the
#              <b>
#               <a href="/wiki/Great_Wall_of_China" title="Great Wall of China">
#                Great Wall of China
#               </a>
#              </b>
#              <i>
#               (pictured)
#              </i>
#              , allowing them to capture Beijing.
#             </li>
#             <li>
#              <a href="/wiki/1816" title="1816">
#               1816
#              </a>
#              – The English poet
#              <a href="/wiki/Samuel_Taylor_Coleridge" title="Samuel Taylor Coleridge">
#               Samuel Taylor Coleridge
#              </a>
#              published one of his most famous poems,
#              <i>
#               <b>
#                <a href="/wiki/Kubla_Khan" title="Kubla Khan">
#                 Kubla Khan
#                </a>
#               </b>
#              </i>
#              .
#             </li>
#             <li>
#              <a href="/wiki/1878" title="1878">
#               1878
#              </a>
#              –
#              <a href="/wiki/Gilbert_and_Sullivan" title="Gilbert and Sullivan">
#               Gilbert and Sullivan
#              </a>
#              's
#              <a href="/wiki/Comic_opera" title="Comic opera">
#               comic opera
#              </a>
#              <i>
#               <b>
#                <a href="/wiki/H.M.S._Pinafore" title="H.M.S. Pinafore">
#                 H.M.S. Pinafore
#                </a>
#               </b>
#              </i>
#              premiered at the
#              <a href="/wiki/Opera_Comique" title="Opera Comique">
#               Opera Comique
#              </a>
#              in London.
#             </li>
#             <li>
#              <a href="/wiki/1961" title="1961">
#               1961
#              </a>
#              – In an address to
#              <a href="/wiki/Joint_session_of_the_United_States_Congress" title="Joint session of the United States Congress">
#               Congress
#              </a>
#              , U.S. president
#              <a href="/wiki/John_F._Kennedy" title="John F. Kennedy">
#               John F. Kennedy
#              </a>
#              announced his support for the
#              <b>
#               <a href="/wiki/Apollo_program" title="Apollo program">
#                Apollo program
#               </a>
#              </b>
#              , with "the goal, before this decade is out, of landing a man on the Moon and returning him safely to the Earth".
#             </li>
#             <li>
#              <a href="/wiki/2011" title="2011">
#               2011
#              </a>
#              – The final episode of
#              <i>
#               <b>
#                <a href="/wiki/The_Oprah_Winfrey_Show" title="The Oprah Winfrey Show">
#                 The Oprah Winfrey Show
#                </a>
#               </b>
#              </i>
#              , the highest-rated daytime
#              <a href="/wiki/Talk_show" title="Talk show">
#               talk show
#              </a>
#              in
#              <a href="/wiki/Television_in_the_United_States" title="Television in the United States">
#               U.S. television
#              </a>
#              history, was broadcast.
#             </li>
#            </ul>
#            <div class="hlist hlist-separated" style="margin-top: 0.5em;">
#             <ul>
#              <li>
#               <b>
#                <a href="/wiki/Princess_Helena_of_the_United_Kingdom" title="Princess Helena of the United Kingdom">
#                 Princess Helena of the United Kingdom
#                </a>
#               </b>
#               (
#               <abbr title="born">
#                b.
#               </abbr>
#               1846)
#              </li>
#              <li>
#               <b>
#                <a href="/wiki/Elizabeth_Kane" title="Elizabeth Kane">
#                 Elizabeth Kane
#                </a>
#               </b>
#               (
#               <abbr title="died">
#                d.
#               </abbr>
#               1909)
#              </li>
#              <li>
#               <b>
#                <a href="/wiki/Ruby_Payne-Scott" title="Ruby Payne-Scott">
#                 Ruby Payne-Scott
#                </a>
#               </b>
#               (
#               <abbr title="died">
#                d.
#               </abbr>
#               1981)
#              </li>
#             </ul>
#            </div>
#            <div style="margin-top: 0.5em;">
#             More anniversaries:
#             <div class="hlist hlist-separated inline nowraplinks">
#              <ul>
#               <li>
#                <a href="/wiki/May_24" title="May 24">
#                 May 24
#                </a>
#               </li>
#               <li>
#                <b>
#                 <a href="/wiki/May_25" title="May 25">
#                  May 25
#                 </a>
#                </b>
#               </li>
#               <li>
#                <a href="/wiki/May_26" title="May 26">
#                 May 26
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class="otd-footer hlist hlist-separated noprint" style="text-align: right;">
#             <ul>
#              <li>
#               <b>
#                <a href="/wiki/Wikipedia:Selected_anniversaries/May" title="Wikipedia:Selected anniversaries/May">
#                 Archive
#                </a>
#               </b>
#              </li>
#              <li>
#               <b>
#                <a class="extiw" href="https://lists.wikimedia.org/mailman/listinfo/daily-article-l" title="mail:daily-article-l">
#                 By email
#                </a>
#               </b>
#              </li>
#              <li>
#               <b>
#                <a href="/wiki/List_of_days_of_the_year" title="List of days of the year">
#                 List of days of the year
#                </a>
#               </b>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <div class="MainPageBG mp-bordered" id="mp-lower">
#        <div id="mp-bottom">
#         <h2 class="mp-h2" id="mp-tfp-h2">
#          <span id="Today.27s_featured_picture">
#          </span>
#          <span class="mw-headline" id="Today's_featured_picture">
#           Today's featured picture
#          </span>
#         </h2>
#         <div id="mp-tfp">
#          <table role="presentation" style="margin:0 3px 3px; width:100%; box-sizing:border-box; text-align:left; background-color:transparent; border-collapse:collapse;">
#           <tbody>
#            <tr>
#             <td style="padding:0 0.9em 0 0; width:300px;">
#              <a class="image" href="/wiki/File:Adonis_blue_(Polyommatus_bellargus)_male_underside_2.jpg" title="Adonis blue">
#               <img alt="Adonis blue" data-file-height="2276" data-file-width="3414" decoding="async" height="200" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/89/Adonis_blue_%28Polyommatus_bellargus%29_male_underside_2.jpg/300px-Adonis_blue_%28Polyommatus_bellargus%29_male_underside_2.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/89/Adonis_blue_%28Polyommatus_bellargus%29_male_underside_2.jpg/450px-Adonis_blue_%28Polyommatus_bellargus%29_male_underside_2.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/89/Adonis_blue_%28Polyommatus_bellargus%29_male_underside_2.jpg/600px-Adonis_blue_%28Polyommatus_bellargus%29_male_underside_2.jpg 2x" width="300"/>
#              </a>
#             </td>
#             <td style="padding:0 6px 0 0">
#              <p>
#               The
#               <b>
#                <a href="/wiki/Adonis_blue" title="Adonis blue">
#                 Adonis blue
#                </a>
#               </b>
#               (
#               <i>
#                Polyommatus bellargus
#               </i>
#               ) is a butterfly in the family
#               <a href="/wiki/Lycaenidae" title="Lycaenidae">
#                Lycaenidae
#               </a>
#               found in Europe and parts of West Asia. This photograph shows the underside of the folded wings of a male, the upper side being a bright, sky-blue; the photograph was taken in a chalk meadow at
#               <a href="/wiki/Yoesden" title="Yoesden">
#                Yoesden Bank
#               </a>
#               in
#               <a href="/wiki/Buckinghamshire" title="Buckinghamshire">
#                Buckinghamshire
#               </a>
#               , England.
#              </p>
#              <p style="text-align:left;">
#               <small>
#                Photograph credit:
#                <a href="/wiki/User:Charlesjsharp" title="User:Charlesjsharp">
#                 Charles J. Sharp
#                </a>
#               </small>
#              </p>
#              <div class="potd-recent" style="text-align:right;">
#               Recently featured:
#               <div class="hlist hlist-separated inline">
#                <ul>
#                 <li>
#                  <a href="/wiki/Template:POTD/2021-05-24" title="Template:POTD/2021-05-24">
#                   Helsinki Cathedral
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/wiki/Template:POTD/2021-05-23" title="Template:POTD/2021-05-23">
#                   <i>
#                    The Crucifixion of Saint Wilgefortis
#                   </i>
#                  </a>
#                 </li>
#                 <li>
#                  <a href="/wiki/Template:POTD/2021-05-22" title="Template:POTD/2021-05-22">
#                   Pied bush chat
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#              <div class="potd-footer hlist hlist-separated noprint" style="text-align:right;">
#               <ul>
#                <li>
#                 <b>
#                  <a href="/wiki/Wikipedia:Picture_of_the_day/Archive" title="Wikipedia:Picture of the day/Archive">
#                   Archive
#                  </a>
#                 </b>
#                </li>
#                <li>
#                 <b>
#                  <a href="/wiki/Wikipedia:Featured_pictures" title="Wikipedia:Featured pictures">
#                   More featured pictures
#                  </a>
#                 </b>
#                </li>
#               </ul>
#              </div>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#       </div>
#       <div class="mp-bordered" id="mp-other-lower">
#        <h2 class="mp-h2" id="mp-other">
#         <span class="mw-headline" id="Other_areas_of_Wikipedia">
#          Other areas of Wikipedia
#         </span>
#        </h2>
#        <div id="mp-other-content">
#         <ul>
#          <li>
#           <b>
#            <a href="/wiki/Wikipedia:Community_portal" title="Wikipedia:Community portal">
#             Community portal
#            </a>
#           </b>
#           – Bulletin board, projects, resources and activities covering a wide range of Wikipedia areas.
#          </li>
#          <li>
#           <b>
#            <a href="/wiki/Wikipedia:Help_desk" title="Wikipedia:Help desk">
#             Help desk
#            </a>
#           </b>
#           – Ask questions about using Wikipedia.
#          </li>
#          <li>
#           <b>
#            <a href="/wiki/Wikipedia:Local_Embassy" title="Wikipedia:Local Embassy">
#             Local embassy
#            </a>
#           </b>
#           – For Wikipedia-related communication in languages other than English.
#          </li>
#          <li>
#           <b>
#            <a href="/wiki/Wikipedia:Reference_desk" title="Wikipedia:Reference desk">
#             Reference desk
#            </a>
#           </b>
#           – Serving as virtual librarians, Wikipedia volunteers tackle your questions on a wide range of subjects.
#          </li>
#          <li>
#           <b>
#            <a href="/wiki/Wikipedia:News" title="Wikipedia:News">
#             Site news
#            </a>
#           </b>
#           – Announcements, updates, articles and press releases on Wikipedia and the Wikimedia Foundation.
#          </li>
#          <li>
#           <b>
#            <a href="/wiki/Wikipedia:Village_pump" title="Wikipedia:Village pump">
#             Village pump
#            </a>
#           </b>
#           – For discussions about Wikipedia itself, including areas for technical issues and policies.
#          </li>
#         </ul>
#        </div>
#        <h2 class="mp-h2" id="mp-sister">
#         <span id="Wikipedia.27s_sister_projects">
#         </span>
#         <span class="mw-headline" id="Wikipedia's_sister_projects">
#          Wikipedia's sister projects
#         </span>
#        </h2>
#        <div id="mp-sister-content">
#         <style data-mw-deduplicate="TemplateStyles:r1007624485">
#          .mw-parser-output #sister-projects-list{display:flex;flex-wrap:wrap}.mw-parser-output #sister-projects-list li{display:inline-block}.mw-parser-output #sister-projects-list li span{font-weight:bold}.mw-parser-output #sister-projects-list li>div{display:inline-block;vertical-align:middle;padding:6px 4px}.mw-parser-output #sister-projects-list li>div:first-child{text-align:center}@media(min-width:360px){.mw-parser-output #sister-projects-list li{width:33%;min-width:20em;white-space:nowrap;flex:1 0 25%}.mw-parser-output #sister-projects-list li>div:first-child{min-width:50px}}
#         </style>
#         <p>
#          Wikipedia is hosted by the
# ...
#       <ul class="vector-menu-content-list">
#        <li class="interlanguage-link interwiki-ar">
#         <a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/" hreflang="ar" lang="ar" title="Arabic">
#          العربية
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-bn">
#         <a class="interlanguage-link-target" href="https://bn.wikipedia.org/wiki/" hreflang="bn" lang="bn" title="Bangla">
#          বাংলা
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-bg">
#         <a class="interlanguage-link-target" href="https://bg.wikipedia.org/wiki/" hreflang="bg" lang="bg" title="Bulgarian">
#          Български
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-bs">
#         <a class="interlanguage-link-target" href="https://bs.wikipedia.org/wiki/" hreflang="bs" lang="bs" title="Bosnian">
#          Bosanski
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ca">
#         <a class="interlanguage-link-target" href="https://ca.wikipedia.org/wiki/" hreflang="ca" lang="ca" title="Catalan">
#          Català
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-cs">
#         <a class="interlanguage-link-target" href="https://cs.wikipedia.org/wiki/" hreflang="cs" lang="cs" title="Czech">
#          Čeština
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-da">
#         <a class="interlanguage-link-target" href="https://da.wikipedia.org/wiki/" hreflang="da" lang="da" title="Danish">
#          Dansk
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-de">
#         <a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/" hreflang="de" lang="de" title="German">
#          Deutsch
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-et">
#         <a class="interlanguage-link-target" href="https://et.wikipedia.org/wiki/" hreflang="et" lang="et" title="Estonian">
#          Eesti
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-el">
#         <a class="interlanguage-link-target" href="https://el.wikipedia.org/wiki/" hreflang="el" lang="el" title="Greek">
#          Ελληνικά
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-es">
#         <a class="interlanguage-link-target" href="https://es.wikipedia.org/wiki/" hreflang="es" lang="es" title="Spanish">
#          Español
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-eo">
#         <a class="interlanguage-link-target" href="https://eo.wikipedia.org/wiki/" hreflang="eo" lang="eo" title="Esperanto">
#          Esperanto
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-eu">
#         <a class="interlanguage-link-target" href="https://eu.wikipedia.org/wiki/" hreflang="eu" lang="eu" title="Basque">
#          Euskara
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fa">
#         <a class="interlanguage-link-target" href="https://fa.wikipedia.org/wiki/" hreflang="fa" lang="fa" title="Persian">
#          فارسی
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fr">
#         <a class="interlanguage-link-target" href="https://fr.wikipedia.org/wiki/" hreflang="fr" lang="fr" title="French">
#          Français
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-gl">
#         <a class="interlanguage-link-target" href="https://gl.wikipedia.org/wiki/" hreflang="gl" lang="gl" title="Galician">
#          Galego
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ko">
#         <a class="interlanguage-link-target" href="https://ko.wikipedia.org/wiki/" hreflang="ko" lang="ko" title="Korean">
#          한국어
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-hr">
#         <a class="interlanguage-link-target" href="https://hr.wikipedia.org/wiki/" hreflang="hr" lang="hr" title="Croatian">
#          Hrvatski
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-id">
#         <a class="interlanguage-link-target" href="https://id.wikipedia.org/wiki/" hreflang="id" lang="id" title="Indonesian">
#          Bahasa Indonesia
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-it">
#         <a class="interlanguage-link-target" href="https://it.wikipedia.org/wiki/" hreflang="it" lang="it" title="Italian">
#          Italiano
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-he">
#         <a class="interlanguage-link-target" href="https://he.wikipedia.org/wiki/" hreflang="he" lang="he" title="Hebrew">
#          עברית
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ka">
#         <a class="interlanguage-link-target" href="https://ka.wikipedia.org/wiki/" hreflang="ka" lang="ka" title="Georgian">
#          ქართული
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-lv">
#         <a class="interlanguage-link-target" href="https://lv.wikipedia.org/wiki/" hreflang="lv" lang="lv" title="Latvian">
#          Latviešu
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-lt">
#         <a class="interlanguage-link-target" href="https://lt.wikipedia.org/wiki/" hreflang="lt" lang="lt" title="Lithuanian">
#          Lietuvių
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-hu">
#         <a class="interlanguage-link-target" href="https://hu.wikipedia.org/wiki/" hreflang="hu" lang="hu" title="Hungarian">
#          Magyar
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-mk">
#         <a class="interlanguage-link-target" href="https://mk.wikipedia.org/wiki/" hreflang="mk" lang="mk" title="Macedonian">
#          Македонски
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ms">
#         <a class="interlanguage-link-target" href="https://ms.wikipedia.org/wiki/" hreflang="ms" lang="ms" title="Malay">
#          Bahasa Melayu
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-nl">
#         <a class="interlanguage-link-target" href="https://nl.wikipedia.org/wiki/" hreflang="nl" lang="nl" title="Dutch">
#          Nederlands
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ja">
#         <a class="interlanguage-link-target" href="https://ja.wikipedia.org/wiki/" hreflang="ja" lang="ja" title="Japanese">
#          日本語
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-no">
#         <a class="interlanguage-link-target" href="https://no.wikipedia.org/wiki/" hreflang="nb" lang="nb" title="Norwegian Bokmål">
#          Norsk bokmål
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-nn">
#         <a class="interlanguage-link-target" href="https://nn.wikipedia.org/wiki/" hreflang="nn" lang="nn" title="Norwegian Nynorsk">
#          Norsk nynorsk
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pl">
#         <a class="interlanguage-link-target" href="https://pl.wikipedia.org/wiki/" hreflang="pl" lang="pl" title="Polish">
#          Polski
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pt">
#         <a class="interlanguage-link-target" href="https://pt.wikipedia.org/wiki/" hreflang="pt" lang="pt" title="Portuguese">
#          Português
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ro">
#         <a class="interlanguage-link-target" href="https://ro.wikipedia.org/wiki/" hreflang="ro" lang="ro" title="Romanian">
#          Română
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ru">
#         <a class="interlanguage-link-target" href="https://ru.wikipedia.org/wiki/" hreflang="ru" lang="ru" title="Russian">
#          Русский
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-simple">
#         <a class="interlanguage-link-target" href="https://simple.wikipedia.org/wiki/" hreflang="en-simple" lang="en-simple" title="Simple English">
#          Simple English
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sk">
#         <a class="interlanguage-link-target" href="https://sk.wikipedia.org/wiki/" hreflang="sk" lang="sk" title="Slovak">
#          Slovenčina
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sl">
#         <a class="interlanguage-link-target" href="https://sl.wikipedia.org/wiki/" hreflang="sl" lang="sl" title="Slovenian">
#          Slovenščina
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sr">
#         <a class="interlanguage-link-target" href="https://sr.wikipedia.org/wiki/" hreflang="sr" lang="sr" title="Serbian">
#          Српски / srpski
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sh">
#         <a class="interlanguage-link-target" href="https://sh.wikipedia.org/wiki/" hreflang="sh" lang="sh" title="Serbo-Croatian">
#          Srpskohrvatski / српскохрватски
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fi">
#         <a class="interlanguage-link-target" href="https://fi.wikipedia.org/wiki/" hreflang="fi" lang="fi" title="Finnish">
#          Suomi
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-sv">
#         <a class="interlanguage-link-target" href="https://sv.wikipedia.org/wiki/" hreflang="sv" lang="sv" title="Swedish">
#          Svenska
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-th">
#         <a class="interlanguage-link-target" href="https://th.wikipedia.org/wiki/" hreflang="th" lang="th" title="Thai">
#          ไทย
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tr">
#         <a class="interlanguage-link-target" href="https://tr.wikipedia.org/wiki/" hreflang="tr" lang="tr" title="Turkish">
#          Türkçe
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-uk">
#         <a class="interlanguage-link-target" href="https://uk.wikipedia.org/wiki/" hreflang="uk" lang="uk" title="Ukrainian">
#          Українська
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vi">
#         <a class="interlanguage-link-target" href="https://vi.wikipedia.org/wiki/" hreflang="vi" lang="vi" title="Vietnamese">
#          Tiếng Việt
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh">
#         <a class="interlanguage-link-target" href="https://zh.wikipedia.org/wiki/" hreflang="zh" lang="zh" title="Chinese">
#          中文
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <footer class="mw-footer" id="footer" role="contentinfo">
#    <ul id="footer-info">
#     <li id="footer-info-lastmod">
#      This page was last edited on 3 February 2021, at 11:11
#      <span class="anonymous-show">
#       (UTC)
#      </span>
#      .
#     </li>
#     <li id="footer-info-copyright">
#      Text is available under the
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">
#       Creative Commons Attribution-ShareAlike License
#      </a>
#      <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# additional terms may apply.  By using this site, you agree to the
#      <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">
#       Terms of Use
#      </a>
#      and
#      <a href="//foundation.wikimedia.org/wiki/Privacy_policy">
#       Privacy Policy
#      </a>
#      . Wikipedia® is a registered trademark of the
#      <a href="//www.wikimediafoundation.org/">
#       Wikimedia Foundation, Inc.
#      </a>
#      , a non-profit organization.
#     </li>
#    </ul>
#    <ul id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=Main_Page&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-statslink">
#      <a href="https://stats.wikimedia.org/#/en.wikipedia.org">
#       Statistics
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#   </footer>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.420","walltime":"0.550","ppvisitednodes":{"value":3873,"limit":1000000},"postexpandincludesize":{"value":114081,"limit":2097152},"templateargumentsize":{"value":7201,"limit":2097152},"expansiondepth":{"value":21,"limit":40},"expensivefunctioncount":{"value":13,"limit":500},"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value":5370,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  401.158      1 -total"," 43.73%  175.407      8 Template:Main_page_image"," 38.50%  154.445      1 Wikipedia:Main_Page/Tomorrow"," 27.70%  111.104      8 Template:Str_number/trim"," 24.27%   97.349      2 Template:Main_page_image/TFA"," 22.87%   91.728     24 Template:If_empty"," 22.05%   88.467      1 Wikipedia:Today's_featured_article/May_25,_2021"," 13.96%   55.983      1 Template:Did_you_know/Queue/1"," 12.72%   51.038      2 Template:Wikipedia_languages"," 11.99%   48.103      1 Wikipedia:Selected_anniversaries/May_25"]},"scribunto":{"limitreport-timeusage":{"value":"0.100","limit":"10.000"},"limitreport-memusage":{"value":2368860,"limit":52428800}},"cachereport":{"origin":"mw1352","timestamp":"20210525011559","ttl":3600,"transientcontent":true}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"Main Page","url":"https:\/\/en.wikipedia.org\/wiki\/Main_Page","sameAs":"http:\/\/www.wikidata.org\/entity\/Q5296","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q5296","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2002-01-26T15:28:12Z","dateModified":"2021-02-03T11:11:30Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/5\/54\/Marshal_Tito_during_the_Second_World_War_in_Yugoslavia%2C_May_1944.jpg","headline":"Wikimedia project page"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":716,"wgHostname":"mw1352"});});
#   </script>
#  </body>
# </html>

# %% [markdown]
# DISPLAYING HEADER TAGS

# %%
soup=BeautifulSoup(page.text, 'html.parser')

# %%
story=soup.find_all(['h1','h2','h3','h4'])

for i in story:
    print(i)
# Out:
# <h1 class="firstHeading" id="firstHeading">Main Page</h1>
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
# <h2 class="mp-h2" id="mp-sister"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span></h2>
# <h2 class="mp-h2" id="mp-lang"><span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span></h2>
# <h2>Navigation menu</h2>
# <h3 class="vector-menu-heading" id="p-personal-label">
# <span>Personal tools</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-namespaces-label">
# <span>Namespaces</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-variants-label">
# <span>Variants</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-views-label">
# <span>Views</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-cactions-label">
# <span>More</span>
# </h3>
# <h3>
# <label for="searchInput">Search</label>
# </h3>
# <h3 class="vector-menu-heading" id="p-navigation-label">
# <span>Navigation</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-interaction-label">
# <span>Contribute</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-tb-label">
# <span>Tools</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-coll-print_export-label">
# <span>Print/export</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-wikibase-otherprojects-label">
# <span>In other projects</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-lang-label">
# <span>Languages</span>
# </h3>

# %%
print('all the header tags:', *story, sep='\n\n')
# Out:
# all the header tags:
#
# <h1 class="firstHeading" id="firstHeading">Main Page</h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
#
# <h2 class="mp-h2" id="mp-sister"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span></h2>
#
# <h2 class="mp-h2" id="mp-lang"><span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span></h2>
#
# <h2>Navigation menu</h2>
#
# <h3 class="vector-menu-heading" id="p-personal-label">
# <span>Personal tools</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-namespaces-label">
# <span>Namespaces</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-variants-label">
# <span>Variants</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-views-label">
# <span>Views</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-cactions-label">
# <span>More</span>
# </h3>
#
# <h3>
# <label for="searchInput">Search</label>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-navigation-label">
# <span>Navigation</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-interaction-label">
# <span>Contribute</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-tb-label">
# <span>Tools</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-coll-print_export-label">
# <span>Print/export</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-wikibase-otherprojects-label">
# <span>In other projects</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-lang-label">
# <span>Languages</span>
# </h3>

# %% [markdown]
# dispalying the header tags from website https://en.wikipedia.org/wiki/Main_Page

# %% [markdown]
# # 2) IMDB’s Top rated 100  movies

# %%
url='https://www.imdb.com/list/ls091520106/?sort=user_rating,desc&st_dt=&mode=detail&page=1'
response=requests.get(url)
soup=BeautifulSoup(response.content,'html.parser')

# %%
movie=[]
year=[]
rating=[]

# %%
movie_data=soup.findAll('div',class_='lister-item mode-detail')

# %%
for store in movie_data:
    name=store.h3.a.text
    movie.append(name)
    year_of_relese=store.h3.find('span', class_='lister-item-year text-muted unbold').text
    year.append(year_of_relese)
    rate=store.find('span', class_='ipl-rating-star__rating').text.replace('\n', '')
    rating.append(rate)

# %%
df_=pd.DataFrame({'Name of movie':movie,'Year of relese':year, 'Ratings':rating})

# %%
df_
# Out:
#                         Name of movie Year of relese Ratings
# 0            The Shawshank Redemption         (1994)     9.3
# 1                       The Godfather         (1972)     9.2
# 2                     The Dark Knight         (2008)       9
# 3              The Godfather: Part II         (1974)       9
# 4                        12 Angry Men         (1957)       9
# ..                                ...            ...     ...
# 95                            Vertigo         (1958)     8.3
# 96                 North by Northwest         (1959)     8.3
# 97                           Das Boot         (1981)     8.3
# 98  M - Eine Stadt sucht einen Mörder         (1931)     8.3
# 99                            The Kid         (1921)     8.3
#
# [100 rows x 3 columns]

# %% [markdown]
# Here is the list of  IMDB’s Top rated 100 movies

# %%
#saving the list
import joblib
joblib.dump(df,'Movies_list.csv')
# Out:
# ['Movies_list.csv']

# %% [markdown]
# # 3) IMDB’s Top rated 100 Indian movies

# %%
url='https://www.imdb.com/list/ls056092300/'
response=requests.get(url)
soup=BeautifulSoup(response.content,'html.parser')

# %%
movie=[]
year=[]
rating=[]

# %%
movie_data=soup.findAll('div',class_='lister-item mode-detail')

# %%
for store in movie_data:
    name=store.h3.a.text
    movie.append(name)
    year_of_relese=store.h3.find('span', class_='lister-item-year text-muted unbold').text
    year.append(year_of_relese)
    rate=store.find('span', class_='ipl-rating-star__rating').text.replace('\n', '')
    rating.append(rate)

# %%
df=pd.DataFrame({'Name of movie':movie,'Year of relese':year, 'Ratings':rating})

# %%
df
# Out:
#                         Name of movie Year of relese Ratings
# 0                     Ship of Theseus         (2012)     8.1
# 1                              Iruvar         (1997)     8.5
# 2                     Kaagaz Ke Phool         (1959)       8
# 3   Lagaan: Once Upon a Time in India         (2001)     8.1
# 4                     Pather Panchali         (1955)     8.6
# ..                                ...            ...     ...
# 95                        Apur Sansar         (1959)     8.5
# 96                        Kanchivaram         (2008)     8.1
# 97                    Monsoon Wedding         (2001)     7.4
# 98                              Black         (2005)     8.2
# 99                            Deewaar         (1975)     8.1
#
# [100 rows x 3 columns]

# %% [markdown]
# Here is the list of IMDB’s Top rated 100 indian movies

# %%
#saving the list

#saving the list
import joblib
joblib.dump(df,'Indian_movies.csv')
# Out:
# ['Indian_movies.csv']

# %% [markdown]
# # 4). 5 books from
# ‘www.bookpage.com’

# %%
page=requests.get('https://bookpage.com/reviews')

page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %% [markdown]
# BOOKS TITLE

# %%
books=soup.find_all('h4',class_='italic')

# %%
books_name=[]
for i in books:
    books_name.append(i.text.replace('\n',''))
books_name[:5]
# Out:
# ['You People',
#  ' ★ Ship in a Bottle',
#  'Tokyo Ever After',
#  'The Kingdoms',
#  'New Yorkers']

# %% [markdown]
# AUTHORS OF THE BOOK

# %%
books_author=soup.find_all('p',class_='sans bold')

# %%
books_authors=[]
for i in books_author:
    books_authors.append(i.text.replace('\n',''))
books_authors[:5]
# Out:
# ['Nikita Lalwani',
#  'Andrew Prahin',
#  'Emiko Jean',
#  'Natasha Pulley',
#  'Craig Taylor, Cast']

# %% [markdown]
# GENRE OF THE BOOKS

# %%
genre=soup.find_all('p',class_='genre-links hidden-phone')

# %%
books_genre=[]
for i in genre:
    books_genre.append(i.text.replace('\n',''))
books_genre[:5]
# Out:
# ['Fiction / Literary Fiction',
#  "Children's / Children's Picture Book",
#  'YA / YA Fiction',
#  'Fiction / Speculative Fiction',
#  'Audio / Nonfiction / Culture']

# %% [markdown]
# REVIEWS

# %%
book_review=soup.find_all('p',class_='excerpt')

# %%
Reviews=[]
for i in book_review:
    Reviews.append(i.text.replace('\n',''))
Reviews[:5]
# Out:
# ["Nikita Lalwani's magical novel invites us to ponder generosity and human kindness.",
#  '',
#  '',
#  'Natasha Pulley balances the topsy-turvy nature of time travel by grounding her story in naval history and a gradually unfolding queer love story.',
#  '“This city barged into conversations,” Craig Taylor says about New Yorkers. With that kind of attitude, you’ll have no choice but to listen in.']

# %%
Books_data=pd.DataFrame({})
Books_data['Name']=books_name
Books_data['Authors']=books_authors
Books_data['Genre']=books_genre
Books_data['Reviews.']=Reviews

# %%
Books_data[:5]
# Out:
#                   Name             Authors  \
# 0           You People      Nikita Lalwani
# 1   ★ Ship in a Bottle       Andrew Prahin
# 2     Tokyo Ever After          Emiko Jean
# 3         The Kingdoms      Natasha Pulley
# 4          New Yorkers  Craig Taylor, Cast
#
#                                   Genre  \
# 0            Fiction / Literary Fiction
# 1  Children's / Children's Picture Book
# 2                       YA / YA Fiction
# 3         Fiction / Speculative Fiction
# 4          Audio / Nonfiction / Culture
#
#                                             Reviews.
# 0  Nikita Lalwani's magical novel invites us to p...
# 1
# 2
# 3  Natasha Pulley balances the topsy-turvy nature...
# 4  “This city barged into conversations,” Craig T...

# %% [markdown]
# Books data with Name ,authors ,Genre and Reviews

# %% [markdown]
# # 5.i) Top 10 ODI teams in men’s cricket teams

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')

page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %% [markdown]
# TOP 10 ODI TEAMS

# %%
odi_teams=soup.find_all('span',class_='u-hide-phablet')

Teams=[]
for i in odi_teams:
    Teams.append(i.text.replace('\n',''))
Teams[:10]
# Out:
# ['New Zealand',
#  'Australia',
#  'India',
#  'England',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'West Indies',
#  'Sri Lanka',
#  'Afghanistan']

# %% [markdown]
# TOP 10 ODI TEAMS's MATCHES

# %%
odi_matches=soup.find_all('td',class_='table-body__cell u-center-text')

Matches=[]
for i in odi_matches:
    Matches.append(i.text.replace('\n',''))
Matches[:10]
# Out:
# ['25', '2,945', '29', '3,344', '27', '3,100', '20', '2,137', '24', '2,323']

# %% [markdown]
# TOP 10 ODI TEAM's POINTS

# %%
odi_points=soup.find_all('td',class_='table-body__cell u-center-text')


Points=[]
for i in odi_points:
    Points.append(i.text.replace('\n',''))
Points[:10]
# Out:
# ['25', '2,945', '29', '3,344', '27', '3,100', '20', '2,137', '24', '2,323']

# %% [markdown]
# TOP 10 ODI TEAM's RATINGS

# %%
odi_ratings=soup.find_all('td',class_='table-body__cell u-text-right rating')


Ratings=[]
for i in odi_ratings:
    Ratings.append(i.text.replace('\n',''))
Ratings[:10]
# Out:
# ['118', '115', '115', '107', '97', '91', '82', '77', '62', '45']

# %% [markdown]
# TOP TEN ODI TEAMS DETAIL

# %%
TOP_TEAN_ODI_TABLE=pd.DataFrame({})
TOP_TEAN_ODI_TABLE['TEAMS']=odi_teams[:10]
TOP_TEAN_ODI_TABLE['MATCHES']=odi_matches[:10]
TOP_TEAN_ODI_TABLE['POINTS']=odi_points[:10]
TOP_TEAN_ODI_TABLE['RATINGS']=odi_ratings[:10]
TOP_TEAN_ODI_TABLE
# Out:
#             TEAMS  MATCHES   POINTS RATINGS
# 0   [New Zealand]     [25]     [25]   [118]
# 1     [Australia]  [2,945]  [2,945]   [115]
# 2         [India]     [29]     [29]   [115]
# 3       [England]  [3,344]  [3,344]   [107]
# 4  [South Africa]     [27]     [27]    [97]
# 5      [Pakistan]  [3,100]  [3,100]    [91]
# 6    [Bangladesh]     [20]     [20]    [82]
# 7   [West Indies]  [2,137]  [2,137]    [77]
# 8     [Sri Lanka]     [24]     [24]    [62]
# 9   [Afghanistan]  [2,323]  [2,323]    [45]

# %% [markdown]
# Top 10 odi cricket teams data

# %% [markdown]
# # 5.ii) Top 10 ODI Batsmen in men

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting')

page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %% [markdown]
# TOP 10 ODI BATSMAN

# %%
names=soup.find_all('td',class_='table-body__cell rankings-table__name name')
Names=[]
for i in names:
    Names.append(i.text.replace('\n',''))
Names[:10]
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'Fakhar Zaman',
#  'Francois du Plessis',
#  'David Warner',
#  'Shai Hope',
#  'Quinton de Kock']

# %% [markdown]
# TOP 10 ODI TEAMS

# %%
teams=soup.find_all('td',class_='table-body__cell nationality-logo rankings-table__team')
Teams=[]
for i in teams:
    Teams.append(i.text.replace('\n',''))
Teams[:10]
# Out:
# ['IND', 'IND', 'NZ', 'AUS', 'ENG', 'PAK', 'SA', 'AUS', 'WI', 'SA']

# %% [markdown]
# TOP 10 ODI TEMAS RATINGS

# %%
rating=soup.find_all('td',class_='table-body__cell rating')
Rating=[]
for i in rating:
    Rating.append(i.text.replace('\n',''))
Rating[:10]
# Out:
# ['857', '825', '801', '791', '785', '778', '778', '773', '773', '756']

# %% [markdown]
# TOP 10 ODI MENS PLAYER DETAIL

# %%
TOP_TEAN_mens_TABLE=pd.DataFrame({})
TOP_TEAN_mens_TABLE['TEAMS']=names[:10]
TOP_TEAN_mens_TABLE['MATCHES']=teams[:10]

TOP_TEAN_mens_TABLE['RATINGS']=rating[:10]
TOP_TEAN_mens_TABLE
# Out:
#                              TEAMS                  MATCHES RATINGS
# 0          [\n, [Virat Kohli], \n]  [\n, [], \n, [IND], \n]   [857]
# 1         [\n, [Rohit Sharma], \n]  [\n, [], \n, [IND], \n]   [825]
# 2          [\n, [Ross Taylor], \n]   [\n, [], \n, [NZ], \n]   [801]
# 3          [\n, [Aaron Finch], \n]  [\n, [], \n, [AUS], \n]   [791]
# 4       [\n, [Jonny Bairstow], \n]  [\n, [], \n, [ENG], \n]   [785]
# 5         [\n, [Fakhar Zaman], \n]  [\n, [], \n, [PAK], \n]   [778]
# 6  [\n, [Francois du Plessis], \n]   [\n, [], \n, [SA], \n]   [778]
# 7         [\n, [David Warner], \n]  [\n, [], \n, [AUS], \n]   [773]
# 8            [\n, [Shai Hope], \n]   [\n, [], \n, [WI], \n]   [773]
# 9      [\n, [Quinton de Kock], \n]   [\n, [], \n, [SA], \n]   [756]

# %% [markdown]
# Top 10 odi mens cricket batting data.

# %% [markdown]
# # 5.iii) Top 10 ODI bowlers

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')

page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %% [markdown]
# TOP 10 ODI BOWLERS

# %%
Names=soup.find_all('td',class_='table-body__cell rankings-table__name name')
names=[]
for i in Names:
    names.append(i.text.replace('\n',''))
names[:10]
# Out:
# ['Mujeeb Ur Rahman',
#  'Matt Henry',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Kagiso Rabada',
#  'Chris Woakes',
#  'Josh Hazlewood',
#  'Pat Cummins',
#  'Mohammad Amir',
#  'Shaheen Afridi']

# %% [markdown]
# TOP 10 ODI BOWLER's TEAM

# %%
teams=soup.find_all('span',class_='table-body__logo-text')
Teams=[]
for i in teams:
    Teams.append(i.text.replace('\n',''))
Teams[:10]
# Out:
# ['AFG', 'NZ', 'IND', 'BAN', 'SA', 'ENG', 'AUS', 'AUS', 'PAK', 'PAK']

# %% [markdown]
# TOP 10 ODI BOWLERS's RATING

# %%
ratings=soup.find_all('td',class_='table-body__cell rating')
Ratings=[]
for i in ratings:
    Ratings.append(i.text.replace('\n',''))
Ratings[:10]
# Out:
# ['708', '691', '690', '668', '666', '665', '660', '646', '638', '634']

# %% [markdown]
# TOP 10 ODI BOWLER's TABLE

# %%
TOP_TEAN_bowlers_TABLE=pd.DataFrame({})
TOP_TEAN_bowlers_TABLE['TEAMS']=names[:10]
TOP_TEAN_bowlers_TABLE['MATCHES']=teams[:10]

TOP_TEAN_bowlers_TABLE['RATING']=rating[:10]
TOP_TEAN_bowlers_TABLE
# Out:
#               TEAMS MATCHES RATING
# 0  Mujeeb Ur Rahman   [AFG]  [857]
# 1        Matt Henry    [NZ]  [825]
# 2    Jasprit Bumrah   [IND]  [801]
# 3      Mehedi Hasan   [BAN]  [791]
# 4     Kagiso Rabada    [SA]  [785]
# 5      Chris Woakes   [ENG]  [778]
# 6    Josh Hazlewood   [AUS]  [778]
# 7       Pat Cummins   [AUS]  [773]
# 8     Mohammad Amir   [PAK]  [773]
# 9    Shaheen Afridi   [PAK]  [708]

# %% [markdown]
# Top 10 odi mens cricket bowling data

# %% [markdown]
# # 6.i) Top 10 ODI teams in women’s cricket

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')

page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %% [markdown]
# TOP 10 ODI WOMENS TEAM

# %%
odi_womens_teams=soup.find_all('span',class_='u-hide-phablet')

womens_team=[]
for i in odi_womens_teams:
    womens_team.append(i.text.replace('\n',''))
womens_team[1:10]
# Out:
# ['South Africa',
#  'England',
#  'India',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Bangladesh',
#  'Sri Lanka',
#  'Ireland']

# %% [markdown]
# TOP 10 ODI WOMENS TEAM PLAYER MATCHES

# %%
odi_womens_matches=soup.find_all('td',class_='table-body__cell u-center-text')

womens_matches=[]
for i in odi_womens_matches:
    womens_matches.append(i.text.replace('\n',''))
womens_matches[:10]
# Out:
# ['24', '2,828', '17', '1,993', '20', '2,226', '21', '1,947', '12', '1,025']

# %% [markdown]
# TOP 10 ODI WOMENS TEAM POINTS

# %%
odi_womens_points=soup.find_all('td',class_='table-body__cell u-center-text')


womens_points=[]
for i in odi_womens_points:
    womens_points.append(i.text.replace('\n',''))
womens_points[:10]
# Out:
# ['24', '2,828', '17', '1,993', '20', '2,226', '21', '1,947', '12', '1,025']

# %% [markdown]
# TOP 10 ODI WOMENS TEAM RATINGS

# %%
odi_womens_ratings=soup.find_all('td',class_='table-body__cell u-text-right rating')


womens_ratings=[]
for i in odi_womens_ratings:
    womens_ratings.append(i.text.replace('\n',''))
womens_ratings[:10]
# Out:
# ['118', '117', '111', '93', '85', '73', '61', '47', '13']

# %% [markdown]
# TOP 10 ODI WOMENS TEAM DETAILS

# %%
TOP_TEAN_womens_ODI_TABLE=pd.DataFrame({})
TOP_TEAN_womens_ODI_TABLE['TEAMS']=odi_womens_teams[:9]
TOP_TEAN_womens_ODI_TABLE['MATCHES']=odi_womens_matches[:9]
TOP_TEAN_womens_ODI_TABLE['POINTS']=odi_womens_points[:9]
TOP_TEAN_womens_ODI_TABLE['RATINGS']=odi_womens_ratings[:9]
TOP_TEAN_womens_ODI_TABLE
# Out:
#             TEAMS  MATCHES   POINTS RATINGS
# 0     [Australia]     [24]     [24]   [118]
# 1  [South Africa]  [2,828]  [2,828]   [117]
# 2       [England]     [17]     [17]   [111]
# 3         [India]  [1,993]  [1,993]    [93]
# 4   [New Zealand]     [20]     [20]    [85]
# 5   [West Indies]  [2,226]  [2,226]    [73]
# 6      [Pakistan]     [21]     [21]    [61]
# 7    [Bangladesh]  [1,947]  [1,947]    [47]
# 8     [Sri Lanka]     [12]     [12]    [13]

# %% [markdown]
# Top odi womens cricket team

# %% [markdown]
# # 6.ii) Top 10 women’s ODI players

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi')

page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %% [markdown]
# TOP 10 ODI WOMENS PLAYER

# %%
players_name=soup.find_all('td',class_='table-body__cell name')
Player_Names=[]
for i in players_name:
    Player_Names.append(i.text.replace('\n',''))
Player_Names[:10]
# Out:
# ['Lizelle Lee',
#  'Alyssa Healy',
#  'Stafanie Taylor',
#  'Meg Lanning',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Mithali Raj',
#  'Natalie Sciver',
#  'Laura Wolvaardt',
#  'Megan Schutt']

# %% [markdown]
# TOP 10 ODI WOMENS PLAYERS TEAMS

# %%
womens_team=soup.find_all('span',class_='table-body__logo-text')
w_teams=[]
for i in womens_team:
    w_teams.append(i.text.replace('\n',''))
w_teams[:10]
# Out:
# ['SA', 'AUS', 'WI', 'AUS', 'NZ', 'IND', 'IND', 'ENG', 'SA', 'AUS']

# %% [markdown]
# TOP 10 ODI WOMENS PLAYER RATINGS

# %%
womens_rating=soup.find_all('td',class_='table-body__cell u-text-right rating')
w_rating=[]
for i in womens_rating:
    w_rating.append(i.text.replace('\n',''))
w_rating[:10]
# Out:
# ['758', '756', '746', '723', '715', '710', '709', '685', '683', '762']

# %% [markdown]
# TOP 10 ODI WOMENS PLAYER DETAILS

# %%
TOP_w_odi_w_TABLE=pd.DataFrame({})
TOP_w_odi_w_TABLE['TEAMS']=players_name[:10]
TOP_w_odi_w_TABLE['MATCHES']=womens_team[:10]

TOP_w_odi_w_TABLE['RATING']=womens_rating[:10]
TOP_w_odi_w_TABLE
# Out:
#                            TEAMS MATCHES RATING
# 0        [\n, [Lizelle Lee], \n]    [SA]  [758]
# 1       [\n, [Alyssa Healy], \n]   [AUS]  [756]
# 2    [\n, [Stafanie Taylor], \n]    [WI]  [746]
# 3        [\n, [Meg Lanning], \n]   [AUS]  [723]
# 4  [\n, [Amy Satterthwaite], \n]    [NZ]  [715]
# 5    [\n, [Smriti Mandhana], \n]   [IND]  [710]
# 6        [\n, [Mithali Raj], \n]   [IND]  [709]
# 7     [\n, [Natalie Sciver], \n]   [ENG]  [685]
# 8    [\n, [Laura Wolvaardt], \n]    [SA]  [683]
# 9       [\n, [Megan Schutt], \n]   [AUS]  [762]

# %% [markdown]
# Top womens odi cricket players

# %% [markdown]
# # 6.iii) Top 10 women’s ODI all-rounder

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder')

page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %% [markdown]
# TOP 10 WOMENS ALLROUNDERS

# %%
w_allrounders_name=soup.find_all('td',class_='table-body__cell rankings-table__name name')
al_Names=[]
for i in allrounders_name:
    al_Names.append(i.text.replace('\n',''))
al_Names[:10]
# Out:
# ['Ellyse Perry',
#  'Stafanie Taylor',
#  'Natalie Sciver',
#  'Deepti Sharma',
#  'Jess Jonassen',
#  'Ashleigh Gardner',
#  'Dane van Niekerk',
#  'Sophie Devine',
#  'Amelia Kerr',
#  'Katherine Brunt']

# %% [markdown]
# TOP 10 WOMENS ALLROUNDERS TEAMS

# %%
w_allrounders_team=soup.find_all('td',class_='table-body__cell nationality-logo rankings-table__team')
w_al_teams=[]
for i in w_allrounders_team:
    w_al_teams.append(i.text.replace('\n',''))
w_al_teams[:10]
# Out:
# ['AUS', 'WI', 'ENG', 'IND', 'AUS', 'AUS', 'SA', 'NZ', 'NZ', 'ENG']

# %% [markdown]
# TOP 10 WOMENS ALLROUNDRS RATINGS

# %%
w_allrounders_rating=soup.find_all('td',class_='table-body__cell rating')
w_al_rating=[]
for i in w_allrounders_rating:
    w_al_rating.append(i.text.replace('\n',''))
w_al_rating[:10]
# Out:
# ['418', '410', '349', '343', '307', '252', '243', '242', '236', '236']

# %% [markdown]
# TOP 10 WOMENS ODI ALLROUNDERS DETAILS

# %%
TOP_w_odi_al_TABLE=pd.DataFrame({})
TOP_w_odi_al_TABLE['NAME']=w_allrounders_name[:10]
TOP_w_odi_al_TABLE['TEAMS']=w_allrounders_team[:10]

TOP_w_odi_al_TABLE['RATING']=w_allrounders_rating[:10]
TOP_w_odi_al_TABLE
# Out:
#                            NAME                    TEAMS RATING
# 0      [\n, [Ellyse Perry], \n]  [\n, [], \n, [AUS], \n]  [418]
# 1   [\n, [Stafanie Taylor], \n]   [\n, [], \n, [WI], \n]  [410]
# 2    [\n, [Natalie Sciver], \n]  [\n, [], \n, [ENG], \n]  [349]
# 3     [\n, [Deepti Sharma], \n]  [\n, [], \n, [IND], \n]  [343]
# 4     [\n, [Jess Jonassen], \n]  [\n, [], \n, [AUS], \n]  [307]
# 5  [\n, [Ashleigh Gardner], \n]  [\n, [], \n, [AUS], \n]  [252]
# 6  [\n, [Dane van Niekerk], \n]   [\n, [], \n, [SA], \n]  [243]
# 7     [\n, [Sophie Devine], \n]   [\n, [], \n, [NZ], \n]  [242]
# 8       [\n, [Amelia Kerr], \n]   [\n, [], \n, [NZ], \n]  [236]
# 9   [\n, [Katherine Brunt], \n]  [\n, [], \n, [ENG], \n]  [236]

# %% [markdown]
# Top 10 allrounders of womens odi cricket  team.

# %% [markdown]
# # 7) a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in

# %%
page=requests.get('https://www.amazon.in/s?bbn=1389401031&rh=n%3A1389401031%2Cp_36%3A1318506031&dc&qid=1621938591&rnid=1318502031&ref=lp_1389401031_nr_p_36_3')

page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %% [markdown]
# SMARTPHONES NAME

# %%
product_name=soup.find_all('span',class_='a-size-base-plus a-color-base a-text-normal')
p_name=[]
for i in product_name:
    p_name.append(i.text.replace('\n',''))
p_name
# Out:
# ['Redmi Note 10 (Shadow Black, 4GB RAM, 64GB Storage) - Amoled Dot Display | 48MP Sony Sensor IMX582 | Snapdragon 678 Processor',
#  'Redmi Note 10 (Aqua Green, 4GB RAM, 64GB Storage)',
#  'Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate',
#  'Redmi Note 10 (Aqua Green, 6GB RAM, 128GB Storage) - Amoled Dot Display | 48MP Sony Sensor IMX582 | Snapdragon 678 Processor',
#  'Samsung Galaxy M12 (Black,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate',
#  'Oppo A31 (Fantasy White, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Redmi 9 Power (Blazing Blue, 4GB RAM, 64GB Storage) - 6000mAh Battery |FHD+ Screen| 48MP Quad Camera',
#  'Redmi Note 9 (Arctic White, 4GB RAM, 64GB Storage) - 48MP Quad Camera & Full HD+ Display',
#  'Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage)',
#  'Redmi Note 10 (Shadow Black, 6GB RAM, 128GB Storage)',
#  'Redmi Note 9 Shadow Black, 4GB RAM, 64GB Storage',
#  'Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storage) - 48MP Quad Camera & Full HD+ Display',
#  'Oppo A31 (Mystery Black, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Redmi Note 10 Pro (Dark Night, 6GB RAM, 128GB Storage) -120hz Super Amoled Display|64MP with 5mp Super Tele- Macro',
#  'Redmi 9 Power (Electric Green, 4GB RAM, 64GB Storage) - 6000mAh Battery |FHD+ Screen| 48MP Quad Camera',
#  'Redmi 9 Power (Mighty Black 4GB RAM 64GB Storage) - 6000mAh Battery |FHD+ Screen | 48MP Quad Camera',
#  'OPPO A74 5G (Fluid Black, 6GB RAM, 128GB Storage)',
#  'OPPO A74 5G (Fantastic Purple, 6GB RAM, 128GB Storage)',
#  'Redmi Note 10S (Shadow Black, 6GB RAM, 128GB Storage) - Super Amoled Display | 64 MP Quad Camera',
#  'Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128GB Storage)',
#  'Samsung Galaxy M12 (White,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate',
#  'Redmi Note 10S (Shadow Black, 6GB RAM, 64GB Storage) - Super Amoled Display | 64 MP Quad Camera',
#  'Samsung Galaxy M12 (Blue,6GB RAM, 128GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate',
#  'Samsung Galaxy M31 (Space Black, 6GB RAM, 128GB Storage)']

# %% [markdown]
# SMARTPHONES PRICE

# %%
product_price=soup.find_all('span',class_='a-price-whole')
p_price=[]
for i in product_price:
    p_price.append(i.text.replace('\n',''))
p_price
# Out:
# ['12,499',
#  '12,499',
#  '10,999',
#  '14,499',
#  '10,999',
#  '10,990',
#  '10,499',
#  '10,999',
#  '14,999',
#  '14,499',
#  '10,999',
#  '10,999',
#  '10,990',
#  '16,999',
#  '10,499',
#  '10,499',
#  '17,990',
#  '17,990',
#  '16,999',
#  '10,999',
#  '14,999',
#  '13,499',
#  '14,999']

# %%
url=('https://m.media-amazon.com/images/I/71QY6JV6FhS._AC_UL640_FMwebp_QL65_.jpg')

# %% [markdown]
# SMARTPHONES RATINGS

# %%
product_rating=soup.find_all('i',class_='a-icon a-icon-star-small a-star-small-4 aok-align-bottom')
p_rating=[]
for i in product_rating:
    p_rating.append(i.text.replace('\n',''))
p_rating
# Out:
# ['4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars']

# %% [markdown]
# SMARTPHONES OVERALL DATA

# %%
SMARTPHONES=pd.DataFrame({})
SMARTPHONES['NAME']=product_name[:14]
SMARTPHONES['PRICE']=product_price[:14]

SMARTPHONES['RATING']=product_rating[:14]
SMARTPHONES
# Out:
#                                                  NAME     PRICE  \
# 0   [Redmi Note 10 (Shadow Black, 4GB RAM, 64GB St...  [12,499]
# 1   [Redmi Note 10 (Aqua Green, 4GB RAM, 64GB Stor...  [12,499]
# 2   [Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storag...  [10,999]
# 3   [Redmi Note 10 (Aqua Green, 6GB RAM, 128GB Sto...  [14,499]
# 4   [Samsung Galaxy M12 (Black,4GB RAM, 64GB Stora...  [10,999]
# 5   [Oppo A31 (Fantasy White, 6GB RAM, 128GB Stora...  [10,990]
# 6   [Redmi 9 Power (Blazing Blue, 4GB RAM, 64GB St...  [10,499]
# 7   [Redmi Note 9 (Arctic White, 4GB RAM, 64GB Sto...  [10,999]
# 8   [Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128G...  [14,999]
# 9   [Redmi Note 10 (Shadow Black, 6GB RAM, 128GB S...  [14,499]
# 10  [Redmi Note 9 Shadow Black, 4GB RAM, 64GB Stor...  [10,999]
# 11  [Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Stora...  [10,999]
# 12  [Oppo A31 (Mystery Black, 6GB RAM, 128GB Stora...  [10,990]
# 13  [Redmi Note 10 Pro (Dark Night, 6GB RAM, 128GB...  [16,999]
#
#                     RATING
# 0   [[4.0 out of 5 stars]]
# 1   [[4.0 out of 5 stars]]
# 2   [[4.0 out of 5 stars]]
# 3   [[4.0 out of 5 stars]]
# 4   [[4.0 out of 5 stars]]
# 5   [[4.2 out of 5 stars]]
# 6   [[4.2 out of 5 stars]]
# 7   [[4.0 out of 5 stars]]
# 8   [[4.2 out of 5 stars]]
# 9   [[4.1 out of 5 stars]]
# 10  [[4.2 out of 5 stars]]
# 11  [[4.2 out of 5 stars]]
# 12  [[4.0 out of 5 stars]]
# 13  [[4.0 out of 5 stars]]

# %%
url
# Out:
# 'https://m.media-amazon.com/images/I/71QY6JV6FhS._AC_UL640_FMwebp_QL65_.jpg'

# %% [markdown]
# # 8)  python program to extract information about the local weather from the National Weather Service

# %%
page=requests.get('https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.YKz8oY3itPY')

page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %% [markdown]
# WEATHER TIME PERIOD

# %%
period=soup.find_all('p',class_='period-name')
w_period=[]
for i in period:
    w_period.append(i.text.replace('\n',''))
w_period
# Out:
# ['Today',
#  'Tonight',
#  'Wednesday',
#  'WednesdayNight',
#  'Thursday',
#  'ThursdayNight',
#  'Friday',
#  'FridayNight',
#  'Saturday']

# %% [markdown]
# WEATHER SHORT DESCRIPTION

# %%
s_description=soup.find_all('p',class_='short-desc')
short_description=[]
for i in s_description:
    short_description.append(i.text.replace('\n',''))
short_description
# Out:
# ['Mostly Sunnythen Sunnyand Breezy',
#  'Mostly Clear',
#  'Sunny thenSunny andBreezy',
#  'Mostly Clearand Breezy',
#  'Sunny andBreezy',
#  'Mostly Clearand Breezythen PartlyCloudy',
#  'Sunny',
#  'Partly Cloudy',
#  'Mostly Sunny']

# %% [markdown]
# WEATHER DETAIL DESCRIPION WITH TEMPRATURE

# %%
d_desc=soup.find_all('div',class_='col-sm-10 forecast-text')
detail_desc=[]
for i in d_desc:
    detail_desc.append(i.text.replace('\n',''))
detail_desc
# Out:
# ['Mostly cloudy through mid morning, then gradual clearing, with a high near 64. Breezy, with a west wind 13 to 18 mph increasing to 19 to 24 mph in the afternoon. Winds could gust as high as 32 mph. ',
#  'Mostly clear, with a low around 49. West southwest wind 15 to 20 mph decreasing to 5 to 10 mph after midnight. Winds could gust as high as 25 mph. ',
#  'Sunny, with a high near 65. Breezy, with a west southwest wind 5 to 15 mph increasing to 15 to 25 mph in the afternoon. Winds could gust as high as 33 mph. ',
#  'Mostly clear, with a low around 49. Breezy, with a west wind 21 to 26 mph, with gusts as high as 34 mph. ',
#  'Sunny, with a high near 67. Breezy, with a west wind 20 to 28 mph, with gusts as high as 37 mph. ',
#  'Mostly clear, with a low around 51. Breezy. ',
#  'Sunny, with a high near 65.',
#  'Partly cloudy, with a low around 51.',
#  'Mostly sunny, with a high near 64.',
#  'Partly cloudy, with a low around 51.',
#  'Sunny, with a high near 68.',
#  'Mostly clear, with a low around 52.',
#  'Sunny, with a high near 72.']

# %% [markdown]
# WEATHER REPORT

# %%
weather_forcast=pd.DataFrame({})
weather_forcast['PERIOD']=period[:7]
weather_forcast['SHORT DESCRIPTION']=s_description[:7]


weather_forcast['DETAIL DESCRIPTION WITH TEMPRATURE IN FAHRENHEIT']=d_desc[:7]

weather_forcast
# Out:
#                    PERIOD                                  SHORT DESCRIPTION  \
# 0         [Today, [], []]     [Mostly Sunny, [], then Sunny, [], and Breezy]
# 1       [Tonight, [], []]                                     [Mostly Clear]
# 2     [Wednesday, [], []]            [Sunny then, [], Sunny and, [], Breezy]
# 3  [Wednesday, [], Night]                     [Mostly Clear, [], and Breezy]
# 4      [Thursday, [], []]                            [Sunny and, [], Breezy]
# 5   [Thursday, [], Night]  [Mostly Clear, [], and Breezy, [], then Partly...
# 6        [Friday, [], []]                                            [Sunny]
#
#     DETAIL DESCRIPTION WITH TEMPRATURE IN FAHRENHEIT
# 0  [Mostly cloudy through mid morning, then gradu...
# 1  [Mostly clear, with a low around 49. West sout...
# 2  [Sunny, with a high near 65. Breezy, with a we...
# 3  [Mostly clear, with a low around 49. Breezy, w...
# 4  [Sunny, with a high near 67. Breezy, with a we...
# 5     [Mostly clear, with a low around 51. Breezy. ]
# 6                      [Sunny, with a high near 65.]

# %% [markdown]
# # 9) a python program to scrape fresher job listings from ‘https://internshala.com/

# %%
page=requests.get('https://internshala.com/fresher-jobs')

page
# Out:
# <Response [200]>

# %% [markdown]
# JOBS

# %%
soup=BeautifulSoup(page.content)

# %%
title=soup.find_all('div',class_='heading_4_5 profile')
jobs_title=[]
for i in title:
    jobs_title.append(i.text.replace('\n',''))
jobs_title
# Out:
# ['Talent Acquisition Executive ',
#  'Full Stack Developer ',
#  'Backend Developer ',
#  'Full Stack Developer ',
#  'Junior Sales Associate ',
#  'Digital Marketing Specialist ',
#  'Android App Developer ',
#  'Associate Data Scientist ',
#  'Junior Software Developer ',
#  'Associate Software Developer ',
#  'Full Stack Developer ',
#  'Operations Executive ',
#  'Associate UI/UX Designer ',
#  'Web Development Trainee ',
#  'Business Development Executive ',
#  'Full Stack Flutter Developer ',
#  'Associate Software Developer ',
#  'Hardware Simulation Engineer ',
#  'Graphic Designer ',
#  'Marketing Analyst ',
#  'Mobile App Developer ',
#  'Software Engineer - AI(NLP)/Front-end(Angular)/Back-end(Python/Java Cloud) ',
#  'Corporate Sales Executive ',
#  'Software Tester ',
#  'Mobile App Developer ',
#  'Junior Backend Developer ',
#  'Social Media Strategist And Copywriter ',
#  'Junior UI Designer ',
#  'Customer Service Executive ',
#  'Business Development Associate ',
#  'JavaScript Developer ',
#  'Software Engineer ',
#  'Business Development Manager (Inside Sales) ',
#  'Proposal & Marketing Engineer ',
#  'Software Engineer Trainee ',
#  'Associate Software Developer ',
#  'Office Manager ',
#  'Technical Recruiter ',
#  'Administrative Assistant ',
#  'Web Developer ']

# %% [markdown]
# COMPANY

# %%
c=soup.find_all('a',class_='link_display_like_text')
company=[]
for i in c:
    company.append(i.text.replace('\n',''))
company
# Out:
# ['                        CrewKarma                    ',
#  '                        Codfirm                    ',
#  '                        WebMOBI                    ',
#  '                        TMBill Software                    ',
#  '                        Kraftshala                    ',
#  '                        Black Jack                    ',
#  '                        Storlyy                    ',
#  '                        Softsensor.ai                    ',
#  '                        ZoryBoard Software Solutions                    ',
#  '                        SNet Labs Private Limited                    ',
#  '                        RavGins International Private Limited (Wobb.ai)                    ',
#  '                        TutorBin                    ',
#  '                        RavGins International Private Limited (Wobb.ai)                    ',
#  '                        Softsensor.ai                    ',
#  '                        Square Select Estates                    ',
#  '                        HeartShirt                    ',
#  '                        Labellerr By Tensor Matics Private Limited                    ',
#  '                        Keysight Technologies                    ',
#  '                        Cynfas                    ',
#  '                        Exhilar Innovative Solutions Private Limited                    ',
#  '                        Wow Labz                    ',
#  '                        RapidKen.AI                    ',
#  '                        Twin Health                    ',
#  '                        Lattice Innovations Private Limited                    ',
#  '                        Fusion Engineering                    ',
#  '                        VPODS.ai                    ',
#  '                        Internshala                    ',
#  '                        Phionike Solutions                    ',
#  '                        Verzeo                    ',
#  '                        Erikka India                    ',
#  '                        Inflolabs                    ',
#  '                        CrewKarma                    ',
#  '                        Vedic Maths Forum India                    ',
#  '                        EnWe Clean Technologies Private Limited                    ',
#  '                        RightRev India Private Limited                    ',
#  '                        Shashank B                    ',
#  '                        Wono Inc                    ',
#  '                        Wono Inc                    ',
#  '                        Wono Inc                    ',
#  '                        Wono Inc                    ']

# %% [markdown]
# CTC

# %%
ctc=soup.find_all('div',class_='item_body')
CTC=[]
for i in ctc:
    CTC.append(i.text.replace('\n','     '))
CTC
# Out:
# ['     Starts\xa0Immediately                             ',
#  '       3 - 5 LPA                                                    ',
#  "24 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       5 - 8 LPA                                                    ',
#  "24 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 LPA                                                    ',
#  "24 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 LPA                                                    ',
#  "24 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       4 LPA                                                    ',
#  "24 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 5 LPA                                                    ',
#  "24 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 3.5 LPA                                                    ',
#  "23 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       4 - 8 LPA                                                    ',
#  "24 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 4 LPA                                                    ',
#  "20 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 3.2 LPA                                                    ',
#  "20 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3.3 - 4 LPA                                                    ',
#  "20 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3.6 - 3.84 LPA                                                    ',
#  "20 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 4 LPA                                                    ',
#  "20 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 5 LPA                                                    ',
#  "20 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 5 LPA                                                    ',
#  "19 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 3.5 LPA                                                    ',
#  "19 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       7 - 10 LPA                                                    ',
#  "23 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       4 - 7 LPA                                                    ',
#  "19 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 LPA                                                    ',
#  "17 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 6 LPA                                                    ',
#  "17 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 5 LPA                                                    ',
#  "17 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       4 - 8 LPA                                                    ',
#  "17 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 4 LPA                                                    ',
#  "17 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 LPA                                                    ',
#  "16 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       4.5 - 5.25 LPA                                                    ',
#  "16 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       4 - 5 LPA                                                    ',
#  "16 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       5 - 6.8 LPA                                                    ',
#  "16 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3.5 - 4 LPA                                                    ',
#  "15 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 LPA                                                    ',
#  "14 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 5 LPA                                                    ',
#  "14 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 5 LPA                                                    ',
#  "13 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 5 LPA                                                    ',
#  "13 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 4 LPA                                                    ',
#  "13 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 - 3.25 LPA                                                    ',
#  "12 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       3 LPA                                                    ',
#  "12 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       5 - 6 LPA                                                    ',
#  "12 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       5.1 - 6.1 LPA                                                    ',
#  "12 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       5.1 - 6.1 LPA                                                    ',
#  "12 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       5 - 6.5 LPA                                                    ',
#  "12 Jun' 21",
#  '     Starts\xa0Immediately                             ',
#  '       5.5 - 6.5 LPA                                                    ',
#  "12 Jun' 21"]

# %% [markdown]
# APPLYING DATE

# %%
date=soup.find_all('div',class_='other_detail_item_row')
a_date=[]
for i in date:
    a_date.append(i.text.replace('\n',''))
a_date
# Out:
# ['                                Start date                            Starts\xa0Immediately                        CTC  3 - 5 LPA                                                    ',
#  "Apply By24 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  5 - 8 LPA                                                    ',
#  "Apply By24 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 LPA                                                    ',
#  "Apply By24 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 LPA                                                    ',
#  "Apply By24 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  4 LPA                                                    ',
#  "Apply By24 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 5 LPA                                                    ',
#  "Apply By24 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 3.5 LPA                                                    ',
#  "Apply By23 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  4 - 8 LPA                                                    ',
#  "Apply By24 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 4 LPA                                                    ',
#  "Apply By20 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 3.2 LPA                                                    ',
#  "Apply By20 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3.3 - 4 LPA                                                    ',
#  "Apply By20 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3.6 - 3.84 LPA                                                    ',
#  "Apply By20 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 4 LPA                                                    ',
#  "Apply By20 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 5 LPA                                                    ',
#  "Apply By20 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 5 LPA                                                    ',
#  "Apply By19 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 3.5 LPA                                                    ',
#  "Apply By19 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  7 - 10 LPA                                                    ',
#  "Apply By23 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  4 - 7 LPA                                                    ',
#  "Apply By19 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 LPA                                                    ',
#  "Apply By17 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 6 LPA                                                    ',
#  "Apply By17 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 5 LPA                                                    ',
#  "Apply By17 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  4 - 8 LPA                                                    ',
#  "Apply By17 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 4 LPA                                                    ',
#  "Apply By17 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 LPA                                                    ',
#  "Apply By16 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  4.5 - 5.25 LPA                                                    ',
#  "Apply By16 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  4 - 5 LPA                                                    ',
#  "Apply By16 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  5 - 6.8 LPA                                                    ',
#  "Apply By16 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3.5 - 4 LPA                                                    ',
#  "Apply By15 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 LPA                                                    ',
#  "Apply By14 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 5 LPA                                                    ',
#  "Apply By14 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 5 LPA                                                    ',
#  "Apply By13 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 5 LPA                                                    ',
#  "Apply By13 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 4 LPA                                                    ',
#  "Apply By13 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 - 3.25 LPA                                                    ',
#  "Apply By12 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  3 LPA                                                    ',
#  "Apply By12 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  5 - 6 LPA                                                    ',
#  "Apply By12 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  5.1 - 6.1 LPA                                                    ',
#  "Apply By12 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  5.1 - 6.1 LPA                                                    ',
#  "Apply By12 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  5 - 6.5 LPA                                                    ',
#  "Apply By12 Jun' 21",
#  '                                Start date                            Starts\xa0Immediately                        CTC  5.5 - 6.5 LPA                                                    ',
#  "Apply By12 Jun' 21"]

# %%
len(date)
# Out:
# 120

# %% [markdown]
# FRESHERS JOB DATA

# %%
JOBS_DATA=pd.DataFrame({})
JOBS_DATA['JOBS']=title
JOBS_DATA['COMPANY']=c

JOBS_DATA['CTC']=ctc[:40]
JOBS_DATA['APPLY BY']=a_date[:40]
JOBS_DATA
# Out:
#                                                  JOBS  \
# 0             [\n, [Talent Acquisition Executive],  ]
# 1                     [\n, [Full Stack Developer],  ]
# 2                        [\n, [Backend Developer],  ]
# 3                     [\n, [Full Stack Developer],  ]
# 4                   [\n, [Junior Sales Associate],  ]
# 5             [\n, [Digital Marketing Specialist],  ]
# 6                    [\n, [Android App Developer],  ]
# 7                 [\n, [Associate Data Scientist],  ]
# 8                [\n, [Junior Software Developer],  ]
# 9             [\n, [Associate Software Developer],  ]
# 10                    [\n, [Full Stack Developer],  ]
# 11                    [\n, [Operations Executive],  ]
# 12                [\n, [Associate UI/UX Designer],  ]
# 13                 [\n, [Web Development Trainee],  ]
# 14          [\n, [Business Development Executive],  ]
# 15            [\n, [Full Stack Flutter Developer],  ]
# 16            [\n, [Associate Software Developer],  ]
# 17            [\n, [Hardware Simulation Engineer],  ]
# 18                        [\n, [Graphic Designer],  ]
# 19                       [\n, [Marketing Analyst],  ]
# 20                    [\n, [Mobile App Developer],  ]
# 21  [\n, [Software Engineer - AI(NLP)/Front-end(An...
# 22               [\n, [Corporate Sales Executive],  ]
# 23                         [\n, [Software Tester],  ]
# 24                    [\n, [Mobile App Developer],  ]
# 25                [\n, [Junior Backend Developer],  ]
# 26  [\n, [Social Media Strategist And Copywriter],  ]
# 27                      [\n, [Junior UI Designer],  ]
# 28              [\n, [Customer Service Executive],  ]
# 29          [\n, [Business Development Associate],  ]
# 30                    [\n, [JavaScript Developer],  ]
# 31                       [\n, [Software Engineer],  ]
# 32  [\n, [Business Development Manager (Inside Sal...
# 33           [\n, [Proposal & Marketing Engineer],  ]
# 34               [\n, [Software Engineer Trainee],  ]
# 35            [\n, [Associate Software Developer],  ]
# 36                          [\n, [Office Manager],  ]
# 37                     [\n, [Technical Recruiter],  ]
# 38                [\n, [Administrative Assistant],  ]
# 39                           [\n, [Web Developer],  ]
#
#                                               COMPANY  \
# 0   [\n                        CrewKarma          ...
# 1   [\n                        Codfirm            ...
# 2   [\n                        WebMOBI            ...
# 3   [\n                        TMBill Software    ...
# 4   [\n                        Kraftshala         ...
# 5   [\n                        Black Jack         ...
# 6   [\n                        Storlyy            ...
# 7   [\n                        Softsensor.ai      ...
# 8   [\n                        ZoryBoard Software ...
# 9   [\n                        SNet Labs Private L...
# 10  [\n                        RavGins Internation...
# 11  [\n                        TutorBin           ...
# 12  [\n                        RavGins Internation...
# 13  [\n                        Softsensor.ai      ...
# 14  [\n                        Square Select Estat...
# 15  [\n                        HeartShirt         ...
# 16  [\n                        Labellerr By Tensor...
# 17  [\n                        Keysight Technologi...
# 18  [\n                        Cynfas             ...
# 19  [\n                        Exhilar Innovative ...
# 20  [\n                        Wow Labz           ...
# 21  [\n                        RapidKen.AI        ...
# 22  [\n                        Twin Health        ...
# 23  [\n                        Lattice Innovations...
# 24  [\n                        Fusion Engineering ...
# 25  [\n                        VPODS.ai           ...
# 26  [\n                        Internshala        ...
# 27  [\n                        Phionike Solutions ...
# 28  [\n                        Verzeo             ...
# 29  [\n                        Erikka India       ...
# 30  [\n                        Inflolabs          ...
# 31  [\n                        CrewKarma          ...
# 32  [\n                        Vedic Maths Forum I...
# 33  [\n                        EnWe Clean Technolo...
# 34  [\n                        RightRev India Priv...
# 35  [\n                        Shashank B         ...
# 36  [\n                        Wono Inc           ...
# 37  [\n                        Wono Inc           ...
# 38  [\n                        Wono Inc           ...
# 39  [\n                        Wono Inc           ...
#
#                                                   CTC  \
# 0   [\n, [Starts ], Immediately\n                 ...
# 1   [\n, [],   3 - 5 LPA                          ...
# 2                                        [24 Jun' 21]
# 3   [\n, [Starts ], Immediately\n                 ...
# 4   [\n, [],   5 - 8 LPA                          ...
# 5                                        [24 Jun' 21]
# 6   [\n, [Starts ], Immediately\n                 ...
# 7   [\n, [],   3 LPA                              ...
# 8                                        [24 Jun' 21]
# 9   [\n, [Starts ], Immediately\n                 ...
# 10  [\n, [],   3 LPA                              ...
# 11                                       [24 Jun' 21]
# 12  [\n, [Starts ], Immediately\n                 ...
# 13  [\n, [],   4 LPA                              ...
# 14                                       [24 Jun' 21]
# 15  [\n, [Starts ], Immediately\n                 ...
# 16  [\n, [],   3 - 5 LPA                          ...
# 17                                       [24 Jun' 21]
# 18  [\n, [Starts ], Immediately\n                 ...
# 19  [\n, [],   3 - 3.5 LPA                        ...
# 20                                       [23 Jun' 21]
# 21  [\n, [Starts ], Immediately\n                 ...
# 22  [\n, [],   4 - 8 LPA                          ...
# 23                                       [24 Jun' 21]
# 24  [\n, [Starts ], Immediately\n                 ...
# 25  [\n, [],   3 - 4 LPA                          ...
# 26                                       [20 Jun' 21]
# 27  [\n, [Starts ], Immediately\n                 ...
# 28  [\n, [],   3 - 3.2 LPA                        ...
# 29                                       [20 Jun' 21]
# 30  [\n, [Starts ], Immediately\n                 ...
# 31  [\n, [],   3.3 - 4 LPA                        ...
# 32                                       [20 Jun' 21]
# 33  [\n, [Starts ], Immediately\n                 ...
# 34  [\n, [],   3.6 - 3.84 LPA                     ...
# 35                                       [20 Jun' 21]
# 36  [\n, [Starts ], Immediately\n                 ...
# 37  [\n, [],   3 - 4 LPA                          ...
# 38                                       [20 Jun' 21]
# 39  [\n, [Starts ], Immediately\n                 ...
#
#                                              APPLY BY
# 0                                   Start date    ...
# 1                                  Apply By24 Jun' 21
# 2                                   Start date    ...
# 3                                  Apply By24 Jun' 21
# 4                                   Start date    ...
# 5                                  Apply By24 Jun' 21
# 6                                   Start date    ...
# 7                                  Apply By24 Jun' 21
# 8                                   Start date    ...
# 9                                  Apply By24 Jun' 21
# 10                                  Start date    ...
# 11                                 Apply By24 Jun' 21
# 12                                  Start date    ...
# 13                                 Apply By23 Jun' 21
# 14                                  Start date    ...
# 15                                 Apply By24 Jun' 21
# 16                                  Start date    ...
# 17                                 Apply By20 Jun' 21
# 18                                  Start date    ...
# 19                                 Apply By20 Jun' 21
# 20                                  Start date    ...
# 21                                 Apply By20 Jun' 21
# 22                                  Start date    ...
# 23                                 Apply By20 Jun' 21
# 24                                  Start date    ...
# 25                                 Apply By20 Jun' 21
# 26                                  Start date    ...
# 27                                 Apply By20 Jun' 21
# 28                                  Start date    ...
# 29                                 Apply By19 Jun' 21
# 30                                  Start date    ...
# 31                                 Apply By19 Jun' 21
# 32                                  Start date    ...
# 33                                 Apply By23 Jun' 21
# 34                                  Start date    ...
# 35                                 Apply By19 Jun' 21
# 36                                  Start date    ...
# 37                                 Apply By17 Jun' 21
# 38                                  Start date    ...
# 39                                 Apply By17 Jun' 21

# %% [markdown]
# FRESHERS JOB OPENINGS DATA

# %% [markdown]
# #                                          ASSIGNMENT SUMMARY

# %% [markdown]
# # 1) python program to display all the header tags from ‘en.wikipedia.org/wiki/Main_Page

# %%
print('all the header tags:', *story, sep='\n\n')
# Out:
# all the header tags:
#
# <h1 class="firstHeading" id="firstHeading">Main Page</h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
#
# <h2 class="mp-h2" id="mp-sister"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span></h2>
#
# <h2 class="mp-h2" id="mp-lang"><span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span></h2>
#
# <h2>Navigation menu</h2>
#
# <h3 class="vector-menu-heading" id="p-personal-label">
# <span>Personal tools</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-namespaces-label">
# <span>Namespaces</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-variants-label">
# <span>Variants</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-views-label">
# <span>Views</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-cactions-label">
# <span>More</span>
# </h3>
#
# <h3>
# <label for="searchInput">Search</label>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-navigation-label">
# <span>Navigation</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-interaction-label">
# <span>Contribute</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-tb-label">
# <span>Tools</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-coll-print_export-label">
# <span>Print/export</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-wikibase-otherprojects-label">
# <span>In other projects</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-lang-label">
# <span>Languages</span>
# </h3>

# %% [markdown]
# # 2) IMDB’s Top rated 100 movies

# %%
df_
# Out:
#                         Name of movie Year of relese Ratings
# 0            The Shawshank Redemption         (1994)     9.3
# 1                       The Godfather         (1972)     9.2
# 2                     The Dark Knight         (2008)       9
# 3              The Godfather: Part II         (1974)       9
# 4                        12 Angry Men         (1957)       9
# ..                                ...            ...     ...
# 95                            Vertigo         (1958)     8.3
# 96                 North by Northwest         (1959)     8.3
# 97                           Das Boot         (1981)     8.3
# 98  M - Eine Stadt sucht einen Mörder         (1931)     8.3
# 99                            The Kid         (1921)     8.3
#
# [100 rows x 3 columns]

# %% [markdown]
# # 3 IMDB’s Top rated 100 Indian movies

# %%
df
# Out:
#                         Name of movie Year of relese Ratings
# 0                     Ship of Theseus         (2012)     8.1
# 1                              Iruvar         (1997)     8.5
# 2                     Kaagaz Ke Phool         (1959)       8
# 3   Lagaan: Once Upon a Time in India         (2001)     8.1
# 4                     Pather Panchali         (1955)     8.6
# ..                                ...            ...     ...
# 95                        Apur Sansar         (1959)     8.5
# 96                        Kanchivaram         (2008)     8.1
# 97                    Monsoon Wedding         (2001)     7.4
# 98                              Black         (2005)     8.2
# 99                            Deewaar         (1975)     8.1
#
# [100 rows x 3 columns]

# %% [markdown]
# # 4) 5 books from¶
# ‘www.bookpage.com

# %%
Books_data
# Out:
#                                  Name                Authors  \
# 0                          You People         Nikita Lalwani
# 1                  ★ Ship in a Bottle          Andrew Prahin
# 2                    Tokyo Ever After             Emiko Jean
# 3                        The Kingdoms         Natasha Pulley
# 4                         New Yorkers     Craig Taylor, Cast
# 5   ★ Hazel Bly and the Deep Blue Sea   Ashley Herring Blake
# 6   ★ The Final Revival of Opal & Nev    Dawnie Walton, Cast
# 7             Sisters of the Neversea  Cynthia Leitich Smith
# 8                ★ American Republics            Alan Taylor
# 9                   ★ Light Perpetual       Francis Spufford
#
#                                      Genre  \
# 0               Fiction / Literary Fiction
# 1     Children's / Children's Picture Book
# 2                          YA / YA Fiction
# 3            Fiction / Speculative Fiction
# 4             Audio / Nonfiction / Culture
# 5                Children's / Middle Grade
# 6       Audio / Fiction / Literary Fiction
# 7                Children's / Middle Grade
# 8  Nonfiction / History / American History
# 9               Fiction / Literary Fiction
#
#                                             Reviews.
# 0  Nikita Lalwani's magical novel invites us to p...
# 1
# 2
# 3  Natasha Pulley balances the topsy-turvy nature...
# 4  “This city barged into conversations,” Craig T...
# 5  Nothing has been the same for Hazel or her fam...
# 6  After listening to this incredible audiobook, ...
# 7
# 8  Pulitzer Prize winner Alan Taylor’s latest Ame...
# 9  The biggest message of Francis Spufford’s seco...

# %% [markdown]
# # 5.i) Top 10 ODI teams in men’s cricket teams

# %%
TOP_TEAN_ODI_TABLE
# Out:
#             TEAMS  MATCHES   POINTS RATINGS
# 0   [New Zealand]     [25]     [25]   [118]
# 1     [Australia]  [2,945]  [2,945]   [115]
# 2         [India]     [29]     [29]   [115]
# 3       [England]  [3,344]  [3,344]   [107]
# 4  [South Africa]     [27]     [27]    [97]
# 5      [Pakistan]  [3,100]  [3,100]    [91]
# 6    [Bangladesh]     [20]     [20]    [82]
# 7   [West Indies]  [2,137]  [2,137]    [77]
# 8     [Sri Lanka]     [24]     [24]    [62]
# 9   [Afghanistan]  [2,323]  [2,323]    [45]

# %% [markdown]
# # 5.ii) Top 10 ODI Batsmen in mens

# %%
TOP_TEAN_mens_TABLE
# Out:
#                              TEAMS                  MATCHES RATINGS
# 0          [\n, [Virat Kohli], \n]  [\n, [], \n, [IND], \n]   [857]
# 1         [\n, [Rohit Sharma], \n]  [\n, [], \n, [IND], \n]   [825]
# 2          [\n, [Ross Taylor], \n]   [\n, [], \n, [NZ], \n]   [801]
# 3          [\n, [Aaron Finch], \n]  [\n, [], \n, [AUS], \n]   [791]
# 4       [\n, [Jonny Bairstow], \n]  [\n, [], \n, [ENG], \n]   [785]
# 5         [\n, [Fakhar Zaman], \n]  [\n, [], \n, [PAK], \n]   [778]
# 6  [\n, [Francois du Plessis], \n]   [\n, [], \n, [SA], \n]   [778]
# 7         [\n, [David Warner], \n]  [\n, [], \n, [AUS], \n]   [773]
# 8            [\n, [Shai Hope], \n]   [\n, [], \n, [WI], \n]   [773]
# 9      [\n, [Quinton de Kock], \n]   [\n, [], \n, [SA], \n]   [756]

# %% [markdown]
# # 5.iii) Top 10 ODI bowlers

# %%
TOP_TEAN_bowlers_TABLE
# Out:
#               TEAMS MATCHES RATING
# 0  Mujeeb Ur Rahman   [AFG]  [857]
# 1        Matt Henry    [NZ]  [825]
# 2    Jasprit Bumrah   [IND]  [801]
# 3      Mehedi Hasan   [BAN]  [791]
# 4     Kagiso Rabada    [SA]  [785]
# 5      Chris Woakes   [ENG]  [778]
# 6    Josh Hazlewood   [AUS]  [778]
# 7       Pat Cummins   [AUS]  [773]
# 8     Mohammad Amir   [PAK]  [773]
# 9    Shaheen Afridi   [PAK]  [708]

# %% [markdown]
# # 6.i) Top 10 ODI teams in women’s cricket

# %%
TOP_TEAN_womens_ODI_TABLE
# Out:
#             TEAMS  MATCHES   POINTS RATINGS
# 0     [Australia]     [24]     [24]   [118]
# 1  [South Africa]  [2,828]  [2,828]   [117]
# 2       [England]     [17]     [17]   [111]
# 3         [India]  [1,993]  [1,993]    [93]
# 4   [New Zealand]     [20]     [20]    [85]
# 5   [West Indies]  [2,226]  [2,226]    [73]
# 6      [Pakistan]     [21]     [21]    [61]
# 7    [Bangladesh]  [1,947]  [1,947]    [47]
# 8     [Sri Lanka]     [12]     [12]    [13]

# %% [markdown]
# # 6.ii) Top 10 women’s ODI players

# %%
TOP_w_odi_w_TABLE
# Out:
#                            TEAMS MATCHES RATING
# 0        [\n, [Lizelle Lee], \n]    [SA]  [758]
# 1       [\n, [Alyssa Healy], \n]   [AUS]  [756]
# 2    [\n, [Stafanie Taylor], \n]    [WI]  [746]
# 3        [\n, [Meg Lanning], \n]   [AUS]  [723]
# 4  [\n, [Amy Satterthwaite], \n]    [NZ]  [715]
# 5    [\n, [Smriti Mandhana], \n]   [IND]  [710]
# 6        [\n, [Mithali Raj], \n]   [IND]  [709]
# 7     [\n, [Natalie Sciver], \n]   [ENG]  [685]
# 8    [\n, [Laura Wolvaardt], \n]    [SA]  [683]
# 9       [\n, [Megan Schutt], \n]   [AUS]  [762]

# %% [markdown]
# # 6.iii) Top 10 women’s ODI all-rounder

# %%
TOP_w_odi_al_TABLE
# Out:
#                            NAME                    TEAMS RATING
# 0      [\n, [Ellyse Perry], \n]  [\n, [], \n, [AUS], \n]  [418]
# 1   [\n, [Stafanie Taylor], \n]   [\n, [], \n, [WI], \n]  [410]
# 2    [\n, [Natalie Sciver], \n]  [\n, [], \n, [ENG], \n]  [349]
# 3     [\n, [Deepti Sharma], \n]  [\n, [], \n, [IND], \n]  [343]
# 4     [\n, [Jess Jonassen], \n]  [\n, [], \n, [AUS], \n]  [307]
# 5  [\n, [Ashleigh Gardner], \n]  [\n, [], \n, [AUS], \n]  [252]
# 6  [\n, [Dane van Niekerk], \n]   [\n, [], \n, [SA], \n]  [243]
# 7     [\n, [Sophie Devine], \n]   [\n, [], \n, [NZ], \n]  [242]
# 8       [\n, [Amelia Kerr], \n]   [\n, [], \n, [NZ], \n]  [236]
# 9   [\n, [Katherine Brunt], \n]  [\n, [], \n, [ENG], \n]  [236]

# %% [markdown]
# # 7)  a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in

# %%
SMARTPHONES
# Out:
#                                                  NAME     PRICE  \
# 0   [Redmi Note 10 (Shadow Black, 4GB RAM, 64GB St...  [12,499]
# 1   [Redmi Note 10 (Aqua Green, 4GB RAM, 64GB Stor...  [12,499]
# 2   [Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storag...  [10,999]
# 3   [Redmi Note 10 (Aqua Green, 6GB RAM, 128GB Sto...  [14,499]
# 4   [Samsung Galaxy M12 (Black,4GB RAM, 64GB Stora...  [10,999]
# 5   [Oppo A31 (Fantasy White, 6GB RAM, 128GB Stora...  [10,990]
# 6   [Redmi 9 Power (Blazing Blue, 4GB RAM, 64GB St...  [10,499]
# 7   [Redmi Note 9 (Arctic White, 4GB RAM, 64GB Sto...  [10,999]
# 8   [Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128G...  [14,999]
# 9   [Redmi Note 10 (Shadow Black, 6GB RAM, 128GB S...  [14,499]
# 10  [Redmi Note 9 Shadow Black, 4GB RAM, 64GB Stor...  [10,999]
# 11  [Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Stora...  [10,999]
# 12  [Oppo A31 (Mystery Black, 6GB RAM, 128GB Stora...  [10,990]
# 13  [Redmi Note 10 Pro (Dark Night, 6GB RAM, 128GB...  [16,999]
#
#                     RATING
# 0   [[4.0 out of 5 stars]]
# 1   [[4.0 out of 5 stars]]
# 2   [[4.0 out of 5 stars]]
# 3   [[4.0 out of 5 stars]]
# 4   [[4.0 out of 5 stars]]
# 5   [[4.2 out of 5 stars]]
# 6   [[4.2 out of 5 stars]]
# 7   [[4.0 out of 5 stars]]
# 8   [[4.2 out of 5 stars]]
# 9   [[4.1 out of 5 stars]]
# 10  [[4.2 out of 5 stars]]
# 11  [[4.2 out of 5 stars]]
# 12  [[4.0 out of 5 stars]]
# 13  [[4.0 out of 5 stars]]

# %% [markdown]
# # 8) python program to extract information about the local weather from the National Weather Service

# %%
weather_forcast
# Out:
#                    PERIOD                                  SHORT DESCRIPTION  \
# 0         [Today, [], []]     [Mostly Sunny, [], then Sunny, [], and Breezy]
# 1       [Tonight, [], []]                                     [Mostly Clear]
# 2     [Wednesday, [], []]            [Sunny then, [], Sunny and, [], Breezy]
# 3  [Wednesday, [], Night]                     [Mostly Clear, [], and Breezy]
# 4      [Thursday, [], []]                            [Sunny and, [], Breezy]
# 5   [Thursday, [], Night]  [Mostly Clear, [], and Breezy, [], then Partly...
# 6        [Friday, [], []]                                            [Sunny]
#
#     DETAIL DESCRIPTION WITH TEMPRATURE IN FAHRENHEIT
# 0  [Mostly cloudy through mid morning, then gradu...
# 1  [Mostly clear, with a low around 49. West sout...
# 2  [Sunny, with a high near 65. Breezy, with a we...
# 3  [Mostly clear, with a low around 49. Breezy, w...
# 4  [Sunny, with a high near 67. Breezy, with a we...
# 5     [Mostly clear, with a low around 51. Breezy. ]
# 6                      [Sunny, with a high near 65.]

# %% [markdown]
# # 9)a python program to scrape fresher job listings from ‘https://internshala.com

# %%
JOBS_DATA
# Out:
#                                                  JOBS  \
# 0             [\n, [Talent Acquisition Executive],  ]
# 1                     [\n, [Full Stack Developer],  ]
# 2                        [\n, [Backend Developer],  ]
# 3                     [\n, [Full Stack Developer],  ]
# 4                   [\n, [Junior Sales Associate],  ]
# 5             [\n, [Digital Marketing Specialist],  ]
# 6                    [\n, [Android App Developer],  ]
# 7                 [\n, [Associate Data Scientist],  ]
# 8                [\n, [Junior Software Developer],  ]
# 9             [\n, [Associate Software Developer],  ]
# 10                    [\n, [Full Stack Developer],  ]
# 11                    [\n, [Operations Executive],  ]
# 12                [\n, [Associate UI/UX Designer],  ]
# 13                 [\n, [Web Development Trainee],  ]
# 14          [\n, [Business Development Executive],  ]
# 15            [\n, [Full Stack Flutter Developer],  ]
# 16            [\n, [Associate Software Developer],  ]
# 17            [\n, [Hardware Simulation Engineer],  ]
# 18                        [\n, [Graphic Designer],  ]
# 19                       [\n, [Marketing Analyst],  ]
# 20                    [\n, [Mobile App Developer],  ]
# 21  [\n, [Software Engineer - AI(NLP)/Front-end(An...
# 22               [\n, [Corporate Sales Executive],  ]
# 23                         [\n, [Software Tester],  ]
# 24                    [\n, [Mobile App Developer],  ]
# 25                [\n, [Junior Backend Developer],  ]
# 26  [\n, [Social Media Strategist And Copywriter],  ]
# 27                      [\n, [Junior UI Designer],  ]
# 28              [\n, [Customer Service Executive],  ]
# 29          [\n, [Business Development Associate],  ]
# 30                    [\n, [JavaScript Developer],  ]
# 31                       [\n, [Software Engineer],  ]
# 32  [\n, [Business Development Manager (Inside Sal...
# 33           [\n, [Proposal & Marketing Engineer],  ]
# 34               [\n, [Software Engineer Trainee],  ]
# 35            [\n, [Associate Software Developer],  ]
# 36                          [\n, [Office Manager],  ]
# 37                     [\n, [Technical Recruiter],  ]
# 38                [\n, [Administrative Assistant],  ]
# 39                           [\n, [Web Developer],  ]
#
#                                               COMPANY  \
# 0   [\n                        CrewKarma          ...
# 1   [\n                        Codfirm            ...
# 2   [\n                        WebMOBI            ...
# 3   [\n                        TMBill Software    ...
# 4   [\n                        Kraftshala         ...
# 5   [\n                        Black Jack         ...
# 6   [\n                        Storlyy            ...
# 7   [\n                        Softsensor.ai      ...
# 8   [\n                        ZoryBoard Software ...
# 9   [\n                        SNet Labs Private L...
# 10  [\n                        RavGins Internation...
# 11  [\n                        TutorBin           ...
# 12  [\n                        RavGins Internation...
# 13  [\n                        Softsensor.ai      ...
# 14  [\n                        Square Select Estat...
# 15  [\n                        HeartShirt         ...
# 16  [\n                        Labellerr By Tensor...
# 17  [\n                        Keysight Technologi...
# 18  [\n                        Cynfas             ...
# 19  [\n                        Exhilar Innovative ...
# 20  [\n                        Wow Labz           ...
# 21  [\n                        RapidKen.AI        ...
# 22  [\n                        Twin Health        ...
# 23  [\n                        Lattice Innovations...
# 24  [\n                        Fusion Engineering ...
# 25  [\n                        VPODS.ai           ...
# 26  [\n                        Internshala        ...
# 27  [\n                        Phionike Solutions ...
# 28  [\n                        Verzeo             ...
# 29  [\n                        Erikka India       ...
# 30  [\n                        Inflolabs          ...
# 31  [\n                        CrewKarma          ...
# 32  [\n                        Vedic Maths Forum I...
# 33  [\n                        EnWe Clean Technolo...
# 34  [\n                        RightRev India Priv...
# 35  [\n                        Shashank B         ...
# 36  [\n                        Wono Inc           ...
# 37  [\n                        Wono Inc           ...
# 38  [\n                        Wono Inc           ...
# 39  [\n                        Wono Inc           ...
#
#                                                   CTC  \
# 0   [\n, [Starts ], Immediately\n                 ...
# 1   [\n, [],   3 - 5 LPA                          ...
# 2                                        [24 Jun' 21]
# 3   [\n, [Starts ], Immediately\n                 ...
# 4   [\n, [],   5 - 8 LPA                          ...
# 5                                        [24 Jun' 21]
# 6   [\n, [Starts ], Immediately\n                 ...
# 7   [\n, [],   3 LPA                              ...
# 8                                        [24 Jun' 21]
# 9   [\n, [Starts ], Immediately\n                 ...
# 10  [\n, [],   3 LPA                              ...
# 11                                       [24 Jun' 21]
# 12  [\n, [Starts ], Immediately\n                 ...
# 13  [\n, [],   4 LPA                              ...
# 14                                       [24 Jun' 21]
# 15  [\n, [Starts ], Immediately\n                 ...
# 16  [\n, [],   3 - 5 LPA                          ...
# 17                                       [24 Jun' 21]
# 18  [\n, [Starts ], Immediately\n                 ...
# 19  [\n, [],   3 - 3.5 LPA                        ...
# 20                                       [23 Jun' 21]
# 21  [\n, [Starts ], Immediately\n                 ...
# 22  [\n, [],   4 - 8 LPA                          ...
# 23                                       [24 Jun' 21]
# 24  [\n, [Starts ], Immediately\n                 ...
# 25  [\n, [],   3 - 4 LPA                          ...
# 26                                       [20 Jun' 21]
# 27  [\n, [Starts ], Immediately\n                 ...
# 28  [\n, [],   3 - 3.2 LPA                        ...
# 29                                       [20 Jun' 21]
# 30  [\n, [Starts ], Immediately\n                 ...
# 31  [\n, [],   3.3 - 4 LPA                        ...
# 32                                       [20 Jun' 21]
# 33  [\n, [Starts ], Immediately\n                 ...
# 34  [\n, [],   3.6 - 3.84 LPA                     ...
# 35                                       [20 Jun' 21]
# 36  [\n, [Starts ], Immediately\n                 ...
# 37  [\n, [],   3 - 4 LPA                          ...
# 38                                       [20 Jun' 21]
# 39  [\n, [Starts ], Immediately\n                 ...
#
#                                              APPLY BY
# 0                                   Start date    ...
# 1                                  Apply By24 Jun' 21
# 2                                   Start date    ...
# 3                                  Apply By24 Jun' 21
# 4                                   Start date    ...
# 5                                  Apply By24 Jun' 21
# 6                                   Start date    ...
# 7                                  Apply By24 Jun' 21
# 8                                   Start date    ...
# 9                                  Apply By24 Jun' 21
# 10                                  Start date    ...
# 11                                 Apply By24 Jun' 21
# 12                                  Start date    ...
# 13                                 Apply By23 Jun' 21
# 14                                  Start date    ...
# 15                                 Apply By24 Jun' 21
# 16                                  Start date    ...
# 17                                 Apply By20 Jun' 21
# 18                                  Start date    ...
# 19                                 Apply By20 Jun' 21
# 20                                  Start date    ...
# 21                                 Apply By20 Jun' 21
# 22                                  Start date    ...
# 23                                 Apply By20 Jun' 21
# 24                                  Start date    ...
# 25                                 Apply By20 Jun' 21
# 26                                  Start date    ...
# 27                                 Apply By20 Jun' 21
# 28                                  Start date    ...
# 29                                 Apply By19 Jun' 21
# 30                                  Start date    ...
# 31                                 Apply By19 Jun' 21
# 32                                  Start date    ...
# 33                                 Apply By23 Jun' 21
# 34                                  Start date    ...
# 35                                 Apply By19 Jun' 21
# 36                                  Start date    ...
# 37                                 Apply By17 Jun' 21
# 38                                  Start date    ...
# 39                                 Apply By17 Jun' 21
