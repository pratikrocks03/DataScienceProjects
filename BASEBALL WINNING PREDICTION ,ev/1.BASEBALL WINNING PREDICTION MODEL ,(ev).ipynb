# %% [markdown]
# # ABOUT THE CASE
#
# BASEBALL CASE STUDY:
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors
#
# -- Output: Number of predicted wins (W)

# %% [markdown]
# # IMPORTING THE DATASETS

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
ds=pd.read_csv('baseball_win.csv')
ds.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# Top 5 heads of the dataset

# %%
ds.shape
# Out:
# (30, 17)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# We have the information of the data frame showing all the columns is not null and ERA column is of float data type and remaining all the columns is of Integer data type.

# %% [markdown]
# There is 30 rows and 17 columns in the dataset.

# %% [markdown]
# # CHECKING NULL VALUES IN THE DATAFRAME

# %%
ds.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# No null values in the dataset.

# %%
# Checking null values through heatmap
sns.heatmap(ds.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# No null values in the dataset.

# %% [markdown]
# # CHECKING DATATYPES OF THE COLUMNS

# %%
ds.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# ERA is  the float type column and remaining all the column is of integer data type.

# %%
ds.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('float64')], dtype=object)

# %% [markdown]
# # SHOWING INTEGER TYPE COLUMNS

# %%
int_col=[]

for x in ds.dtypes.index:
    if ds.dtypes[x]=='int64':
        int_col.append(x)
        
int_col
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %% [markdown]
# Here 'W' column is our target column.

# %% [markdown]
# # CHECKING UNIQUE VALUES IN THE COLUMNS

# %%
ds['CG'].unique()
# Out:
# array([ 2, 11,  7,  3,  0,  1,  5,  6,  4], dtype=int64)

# %% [markdown]
# We have 9 unique values in 'CG' column.

# %%
ds['SHO'].unique()
# Out:
# array([ 8, 12, 10,  9,  4, 13, 15, 21,  7, 14, 18,  6], dtype=int64)

# %% [markdown]
# We have 12 unique values in 'SHO' column.

# %% [markdown]
# In other columns, many values is lying there so not checking uniqueness.

# %% [markdown]
# # CHECKING VALUE COUNTS OF THE COLUMNS

# %%
for col in ds:
    print(col)
    print(df[col].value_counts())
    print()
# Out:
# W
# 68     3
# 83     2
# 74     2
# 76     2
# 81     2
# 64     1
# 93     1
# 92     1
# 90     1
# 88     1
# 87     1
# 86     1
# 85     1
# 84     1
# 80     1
# 97     1
# 100    1
# 78     1
# 63     1
# 79     1
# 71     1
# 67     1
# 98     1
# 95     1
# Name: W, dtype: int64
#
# R
# 6.545350    2
# 6.535241    2
# 6.542472    1
# 6.792344    1
# 6.493754    1
# 6.579251    1
# 6.638568    1
# 6.555357    1
# 6.502790    1
# 6.591674    1
# 6.546785    1
# 6.461468    1
# 6.432940    1
# 6.602588    1
# 6.486161    1
# 6.569481    1
# 6.350886    1
# 6.617403    1
# 6.526495    1
# 6.484635    1
# 6.439350    1
# 6.467699    1
# 6.621406    1
# 6.472346    1
# 6.418365    1
# 6.584791    1
# 6.476972    1
# 6.505784    1
# Name: R, dtype: int64
#
# AB
# 5485    2
# 5571    1
# 5605    1
# 5491    1
# 5565    1
# 5457    1
# 5428    1
# 5420    1
# 5567    1
# 5480    1
# 5439    1
# 5484    1
# 5417    1
# 5544    1
# 5527    1
# 5572    1
# 5600    1
# 5533    1
# 5467    1
# 5529    1
# 5463    1
# 5459    1
# 5649    1
# 5511    1
# 5385    1
# 5640    1
# 5575    1
# 5509    1
# 5631    1
# Name: AB, dtype: int64
#
# H
# 1363    2
# 1346    1
# 1374    1
# 1462    1
# 1397    1
# 1395    1
# 1479    1
# 1324    1
# 1515    1
# 1386    1
# 1383    1
# 1382    1
# 1381    1
# 1379    1
# 1378    1
# 1370    1
# 1349    1
# 1497    1
# 1331    1
# 1495    1
# 1494    1
# 1405    1
# 1361    1
# 1486    1
# 1420    1
# 1419    1
# 1480    1
# 1351    1
# 1341    1
# Name: H, dtype: int64
#
# 2B
# 272    3
# 288    2
# 289    2
# 277    2
# 274    2
# 278    2
# 260    2
# 263    1
# 265    1
# 300    1
# 236    1
# 251    1
# 295    1
# 294    1
# 292    1
# 243    1
# 308    1
# 262    1
# 246    1
# 279    1
# 257    1
# 303    1
# Name: 2B, dtype: int64
#
# 3B
# 27    3
# 32    2
# 49    2
# 17    2
# 39    2
# 26    2
# 29    1
# 22    1
# 21    1
# 20    1
# 19    1
# 18    1
# 48    1
# 33    1
# 46    1
# 13    1
# 44    1
# 42    1
# 40    1
# 37    1
# 36    1
# 34    1
# 30    1
# Name: 3B, dtype: int64
#
# HR
# 136    2
# 177    2
# 167    2
# 130    1
# 156    1
# 186    1
# 120    1
# 176    1
# 172    1
# 171    1
# 232    1
# 230    1
# 100    1
# 161    1
# 154    1
# 198    1
# 217    1
# 151    1
# 212    1
# 146    1
# 145    1
# 148    1
# 141    1
# 140    1
# 139    1
# 137    1
# 187    1
# Name: HR, dtype: int64
#
# BB
# 478    2
# 426    1
# 486    1
# 475    1
# 570    1
# 506    1
# 503    1
# 436    1
# 563    1
# 496    1
# 490    1
# 439    1
# 435    1
# 554    1
# 488    1
# 418    1
# 387    1
# 412    1
# 539    1
# 375    1
# 471    1
# 533    1
# 404    1
# 567    1
# 461    1
# 457    1
# 455    1
# 388    1
# 383    1
# Name: BB, dtype: int64
#
# SO
# 1150    2
# 1344    1
# 1107    1
# 1148    1
# 1274    1
# 1258    1
# 1336    1
# 1267    1
# 1264    1
# 1327    1
# 1518    1
# 1259    1
# 1322    1
# 1255    1
# 1312    1
# 1283    1
# 1119    1
# 1310    1
# 1299    1
# 1331    1
# 1392    1
# 1233    1
# 1231    1
# 973     1
# 1227    1
# 1290    1
# 1159    1
# 1157    1
# 1151    1
# Name: SO, dtype: int64
#
# SB
# 69     3
# 88     2
# 68     1
# 97     1
# 59     1
# 121    1
# 52     1
# 51     1
# 87     1
# 112    1
# 44     1
# 104    1
# 101    1
# 98     1
# 93     1
# 95     1
# 134    1
# 57     1
# 86     1
# 84     1
# 83     1
# 82     1
# 132    1
# 78     1
# 71     1
# 70     1
# 63     1
# Name: SB, dtype: int64
#
# RA
# 640    1
# 641    1
# 700    1
# 635    1
# 675    1
# 760    1
# 627    1
# 693    1
# 698    1
# 754    1
# 753    1
# 618    1
# 809    1
# 678    1
# 613    1
# 803    1
# 737    1
# 608    1
# 670    1
# 733    1
# 731    1
# 729    1
# 726    1
# 596    1
# 595    1
# 525    1
# 844    1
# 713    1
# 642    1
# 701    1
# Name: RA, dtype: int64
#
# ER
# 577    1
# 643    1
# 700    1
# 572    1
# 698    1
# 630    1
# 694    1
# 557    1
# 746    1
# 553    1
# 680    1
# 677    1
# 546    1
# 609    1
# 799    1
# 478    1
# 682    1
# 604    1
# 601    1
# 664    1
# 597    1
# 532    1
# 659    1
# 749    1
# 655    1
# 653    1
# 652    1
# 584    1
# 646    1
# 638    1
# Name: ER, dtype: int64
#
# ERA
# 3.62    1
# 4.31    1
# 3.57    1
# 3.74    1
# 3.94    1
# 4.02    1
# 5.04    1
# 3.67    1
# 4.24    1
# 4.69    1
# 4.41    1
# 4.16    1
# 3.43    1
# 4.14    1
# 4.03    1
# 3.21    1
# 4.28    1
# 3.36    1
# 4.04    1
# 3.80    1
# 3.72    1
# 3.44    1
# 4.07    1
# 4.64    1
# 2.94    1
# 3.73    1
# 4.09    1
# 4.33    1
# 4.05    1
# 3.98    1
# Name: ERA, dtype: int64
#
# CG
# 0.000000    7
# 1.394959    4
# 0.832555    4
# 1.048147    3
# 1.338566    3
# 0.880720    3
# 1.268636    3
# 1.177410    2
# 1.548514    1
# Name: CG, dtype: int64
#
# SHO
# 12    7
# 10    5
# 13    3
# 4     2
# 7     2
# 8     2
# 9     2
# 15    2
# 21    2
# 6     1
# 14    1
# 18    1
# Name: SHO, dtype: int64
#
# SV
# 35    4
# 45    3
# 41    3
# 40    2
# 44    2
# 48    2
# 47    1
# 60    1
# 56    1
# 28    1
# 54    1
# 50    1
# 34    1
# 46    1
# 43    1
# 39    1
# 38    1
# 37    1
# 36    1
# 62    1
# Name: SV, dtype: int64
#
# E
# 4.454347    3
# 4.477337    3
# 4.499810    3
# 4.343805    2
# 4.532599    2
# 4.553877    2
# 4.356709    1
# 4.615121    1
# 4.804021    1
# 4.762174    1
# 4.317488    1
# 4.753590    1
# 4.564348    1
# 4.543295    1
# 4.442651    1
# 4.836282    1
# 4.709530    1
# 4.574711    1
# 4.779123    1
# 4.369448    1
# 4.521789    1
# Name: E, dtype: int64

# %% [markdown]
# # VISUALIZATION OF DATAFRAME

# %%
# through count plot
ax=sns.countplot(x='CG',data=ds)
print(ds['CG'].value_counts())
# Out:
# 1     7
# 2     4
# 7     4
# 0     3
# 3     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: CG, dtype: int64

# %% [markdown]
# In 'CG' column only yellow colored bar is showing maximum number of counts and green colored bar is showing minimum number of counts , that is 7 and 1 respectively.
# other than that all the bars are normally distributed not much noticable difference between them.

# %%
# through count plot
ax=sns.countplot(x='SHO',data=ds)
print(ds['SHO'].value_counts())
# Out:
# 12    7
# 10    5
# 13    3
# 4     2
# 7     2
# 8     2
# 9     2
# 15    2
# 21    2
# 6     1
# 14    1
# 18    1
# Name: SHO, dtype: int64

# %% [markdown]
# The total number unique values in 'SHO' column is 12, and the bar showing on 12 is of maximum number of counts that is 7 ,and the bar showing on the 10 is the count of 5.
# other than that all the bars are normally distributed ,not  much noticable difference between them.

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
ds.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between R  and W')
sns.scatterplot(ds['R'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between R  and W'}, xlabel='R', ylabel='W'>

# %% [markdown]
# Scatter plot showing the postive comparison with an outlier.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between AB  and W')
sns.scatterplot(ds['AB'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between AB  and W'}, xlabel='AB', ylabel='W'>

# %% [markdown]
# Scatter plot is showing positivity with spreadness.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between H  and W')
sns.scatterplot(ds['H'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between H  and W'}, xlabel='H', ylabel='W'>

# %% [markdown]
# In this scatterplot data is very spread.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between 2B    and W')
sns.scatterplot(ds['2B'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between 2B    and W'}, xlabel='2B', ylabel='W'>

# %% [markdown]
# In this scatter plot data is spreaded with postive comparison.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between  3B and W')
sns.scatterplot(ds['3B'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between  3B and W'}, xlabel='3B', ylabel='W'>

# %% [markdown]
# Spreadness of the data is present in the scatter plot.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between HR  and W')
sns.scatterplot(ds['HR'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between HR  and W'}, xlabel='HR', ylabel='W'>

# %% [markdown]
# In this scatterplot data is spreaded with positivity.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between happiness BB  and W')
sns.scatterplot(ds['BB'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between happiness BB  and W'}, xlabel='BB', ylabel='W'>

# %% [markdown]
# Positive comparison between 'BB' and 'W'.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between  SO and W')
sns.scatterplot(ds['SO'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between  SO and W'}, xlabel='SO', ylabel='W'>

# %% [markdown]
# Scatter plot is showing comparison having an outlier.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between SB  and W')
sns.scatterplot(ds['SB'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between SB  and W'}, xlabel='SB', ylabel='W'>

# %% [markdown]
# Data is spreaded in this scatter plot.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between RA and W')
sns.scatterplot(ds['RA'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between RA and W'}, xlabel='RA', ylabel='W'>

# %% [markdown]
# Scatter plot is showing negativity between 'RA' and "w".

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between ER  and W')
sns.scatterplot(ds['ER'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between ER  and W'}, xlabel='ER', ylabel='W'>

# %% [markdown]
# In this Scatter plot negativity is present between 'ER' and 'W.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between happiness ERA  and W')
sns.scatterplot(ds['ERA'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between happiness ERA  and W'}, xlabel='ERA', ylabel='W'>

# %% [markdown]
# Negative comparison in between 'ERA' and 'W' in the scatter plot.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between CG  and W')
sns.scatterplot(ds['CG'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between CG  and W'}, xlabel='CG', ylabel='W'>

# %% [markdown]
# little positivity with spreadness of the data.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between SHO  and W')
sns.scatterplot(ds['SHO'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between SHO  and W'}, xlabel='SHO', ylabel='W'>

# %% [markdown]
# Scatter plot is showing positive comparison between 'SHO' and 'W'.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between SV  and W')
sns.scatterplot(ds['SV'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between SV  and W'}, xlabel='SV', ylabel='W'>

# %% [markdown]
# In this scatter plot positivity is present between "Sv" and 'W'.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between  E  and W')
sns.scatterplot(ds['E'], ds['W'],hue=ds['W'])
# Out:
# <AxesSubplot:title={'center':' comparison between  E  and W'}, xlabel='E', ylabel='W'>

# %% [markdown]
# Scatting plot is showing spreadness in groups with an outliers.

# %%
sns.pairplot(df,hue='W')

# %% [markdown]
# Pair plot is showing all the distributions , postivity, negativity , outliers and many more among each of the column.

# %% [markdown]
# # STATISTICAL SUMMARY

# %%
ds.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(ds.describe(),annot=True,linewidths =0.1,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Mean and Median is approx same in every column.
#
# since we have no missing values in the data frame ,so value counts is same for all the columns.
#
# Not much difference between 75th percentile and Maximum in any of the column.

# %% [markdown]
# # CORRELATION MATRIX

# %%
cor=ds.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
plt.figure(figsize=(22,7))
sns.heatmap(ds.corr(),annot=True,linewidths =0.1,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# SV column is showing positive correlation with W.
#
# SHO column is showing some positive correlation with W.
#
# R and 2B column is showing some positive correlation with W.
#
# BB column is showing positive correlation with W.
#
# RA ER and ERA columns is showing negative correlation with W.

# %% [markdown]
# # CHECKING THE COLUMNS WHICH ARE POSITIVELY AND NEGATIVE CORRELATED WITH THE TARGET COLUMNS

# %%
plt.figure(figsize=(22,7))
ds.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=20)
plt.show()

# %% [markdown]
# ER RA and ERA is showing negative correlation with W.
#
# we can say all the columns is showing correlations with W .

# %% [markdown]
# # CHECKING SKEWNESS

# %%
ds.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# columns is in range between +.5 and -.5 are not skewed.
#
# skewed columns are:
#
#     R, H ,CG ,SV ,

# %% [markdown]
# # CHECKING OUTLIERS

# %%
ds.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
ds['R'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is present in this column.

# %%
df['AB'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is not present in this column.

# %%
ds['H'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is not present in this column.

# %%
ds['2B'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is not present in this column.

# %%
ds['3B'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is not present in this column.

# %%
ds['HR'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is not present in this column.

# %%
df['BB'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is not present in this column.

# %%
ds['SO'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is not present in this column.

# %%
ds['SB'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is not present in this column.

# %%
ds['RA'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is not present in this column.

# %%
ds['ER'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is not present in this column.

# %%
ds['ERA'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is present in this column.

# %%
ds['CG'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is not present in this column.

# %%
ds['SHO'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is present in this column

# %%
ds['SV'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outlier is very close.

# %%
ds['E'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# some outliers  are present in this column.

# %% [markdown]
# # OUTLIER REMOVAL

# %%
ds.shape
# Out:
# (30, 17)

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(ds))
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
ds_new_z=ds[(z<3).all(axis=1)]
ds_new_z
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
ds_new_z.shape
# Out:
# (29, 17)

# %% [markdown]
# one row has been removed as a outlier.

# %% [markdown]
# # REMOVING SKEWNESS

# %%
ds_new_z.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# Since ouliers has been removed then automatically some skewness has removed.

# %% [markdown]
# # SEPRATING THE COLUMNS INTO FEATURES AND TARGET

# %%
x=ds_new_z.drop('W',axis=1)
y=ds_new_z['W']

# %%
x.shape
# Out:
# (29, 16)

# %%
y.shape
# Out:
# (29,)

# %% [markdown]
# # Lets bring all features to a common scale

# %%
# Lets bring all features to a common scale

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(ds_new_z)


x=pd.DataFrame(x,columns=ds_new_z.columns)

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=.22, random_state=43)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (22, 17)
# (7, 17)
# (22,)
# (7,)

# %% [markdown]
# # MODEL BUILDING

# %%
# importing libraries
from sklearn.linear_model import LinearRegression ,Lasso ,Ridge ,ElasticNet
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import cross_val_score

# %%
#for Linear Regression

lr=LinearRegression()
lr.fit(x_train,y_train)
pred_y=lr.predict(x_test)
print('r2 score',r2_score(y_test,pred_y))

print('error')
print('mean absolute error', mean_absolute_error(y_test,pred_y))
print('mean squared error', mean_squared_error(y_test,pred_y))

print('root mean squared error', np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score 1.0
# error
# mean absolute error 2.030122102171715e-14
# mean squared error 5.769954049616544e-28
# root mean squared error 2.402072865176355e-14

# %%
# For Linear Regression (cross validation)


score=cross_val_score(lr,x,y,cv=5)
print('cv score',np.mean(score))
# Out:
# cv score 1.0

# %% [markdown]
# r2 score and cv score is predicting 100 % accuracy for Linear Regression.

# %% [markdown]
# # REGULARIZATION

# %%
#For Lasso
from sklearn.linear_model import Lasso

ls=Lasso()

ls.fit(x_train,y_train)
pred_y=ls.predict(x_test)
print('r2 score',r2_score(y_test,pred_y))

print('error')
print('mean absolute error', mean_absolute_error(y_test,pred_y))
print('mean squared error', mean_squared_error(y_test,pred_y))

print('root mean squared error', np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score 0.9929048040898252
# error
# mean absolute error 0.45210511210674603
# mean squared error 0.34954699851350984
# root mean squared error 0.5912249982143092

# %%
# For Lasso (cross validation)


score=cross_val_score(ls,x,y,cv=5)
print('cv score',np.mean(score))
# Out:
# cv score 0.9846487299081306

# %% [markdown]
# r2 score is predicting 99% and cv score is predicting 98% accuracy for Lasso.

# %%
# for Ridge
from sklearn.linear_model import Ridge

#For Ridge

rd=Ridge()

rd.fit(x_train,y_train)
pred_y=rd.predict(x_test)
print('r2 score',r2_score(y_test,pred_y))

print('error')
print('mean absolute error', mean_absolute_error(y_test,pred_y))
print('mean squared error', mean_squared_error(y_test,pred_y))

print('root mean squared error', np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score 0.8322665035194654
# error
# mean absolute error 2.0101891078312173
# mean squared error 8.263442051102256
# root mean squared error 2.874620331644208

# %%
# For Ridge (cross  validation)


score=cross_val_score(rd,x,y,cv=5)
print('cv score',np.mean(score))
# Out:
# cv score 0.8863614050843956

# %% [markdown]
# r2 score is predicting 83% and cv score is predicting 88% accuracy score for Ridge.

# %%
#For ElasticNet
from sklearn.linear_model import ElasticNet


en=ElasticNet()

en.fit(x_train,y_train)
pred_y=en.predict(x_test)
print('r2 score',r2_score(y_test,pred_y))

print('error')
print('mean absolute error', mean_absolute_error(y_test,pred_y))
print('mean squared error', mean_squared_error(y_test,pred_y))

print('root mean squared error', np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score 0.820311074096963
# error
# mean absolute error 2.240200818460392
# mean squared error 8.85242994142717
# root mean squared error 2.975303336036037

# %%
#For ElasticNet (cross validation)

score=cross_val_score(en,x,y,cv=5)
print('cv score',np.mean(score))
# Out:
# cv score 0.6870807864439529

# %% [markdown]
# r2 score is predicting 82 % and ElasticNet is predicting 68% accuracy.

# %% [markdown]
#  # CLASSIFICATION ALGORITHMS A REGRESSION MODEL

# %%
from sklearn.svm import SVR

kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x_train,y_train)
    print(sv.score(x_train,y_train))
# Out:
# 0.9924738704144995
# 0.5225516514472065
# 0.29430407205436726

# %% [markdown]
# Support vector regression is predicting 99% score for kernel 'liner', 52% for kernel 'poly' and 29% score for kernel 'rbf'.

# %% [raw]
# Above predictions from the model , we can say that our model is performing extremly well,
#
# and Linear regression model is predicting 100 % accuracy in both r2 score and cross validation score.

# %% [markdown]
# # GRAPHH SHOWING THE PERFORMANCE OF MODEL

# %%
# Linear Regression

plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_y, color='r')
plt.plot(y_test,y_test, color='b')
plt.xlabel('actual',fontsize=14)
plt.ylabel('predicted',fontsize=18)
plt.show()

# %% [markdown]
# Best fit line is covering most of the data points which shows good for the model.

# %% [markdown]
#  # ENSEMBLE TECHNIQUE

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='auto')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print('r2 score:', rfs*100)

rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('cross val score:',rfc*100)
# Out:
# r2 score: 94.610173985087
# cross val score: 80.64948431675506

# %% [markdown]
# we are getting model accuracy is 94.61% and cross validation  as 80.64% which shows our model is performing  well.

# %% [markdown]
# # SAVING THE MODEL

# %%
import pickle
filename='baseball_win_pred.pkl'
pickle.dump(rf, open(filename, 'wb'))

# %% [markdown]
# # CONCLUSION

# %%
loaded_model=pickle.load(open('baseball_win_pred.pkl','rb'))
result=loaded_model.score(x_test, y_test)
print(result)
# Out:
# 0.94610173985087

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=['predicted','original'])
conclusion
# Out:
#                0      1      2      3      4      5      6
# predicted  91.01  76.41  68.67  81.52  84.05  77.94  85.44
# original   91.01  76.41  68.67  81.52  84.05  77.94  85.44

# %% [markdown]
# Above predictions from the model , we can say that our model is performing extremly well, we are getting 94% accuracy .

# %% [markdown]
# With the help of this MODEL, I learnt how to done EDA.
#
# I also learnt ,making use of packages like matplotlib and seaborn to develop better insights of the data.
#
# I have also learnt how to remove outliers and skewness to predict better accuracy.
#
# I have also seen the impacts on the columns on target columns..
#
# I came to know through the analysis ,which model will predict better accuracy.
#
# This project helped me to gain deep knowledge , and also get to know where to use models.
#
# ​
